# %% [markdown]
# # 기능 1 : 단어 추출에서 context 를 가진 조합으로
#
# ![alt text](img_june15.png "딥서치 참고자료")
#
# 저번에 보인 기능을 참고해보면 뉴스에서 특정 키워드들을 추출했다. 이것을 한단계 더 나아가서 특정 단일 키워드가 아닌, 여러 키워드의 조합을 추출할려고 시도해보았다.

# %%
from konlpy.tag import Mecab
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from gensim import corpora
import gensim
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib
from pandas.plotting import register_matplotlib_converters
import networkx as nx

## 시각화를 위한 library
import matplotlib.pyplot as plt
import seaborn as sns

import text_helpers as t_helper

from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


sns.set()
register_matplotlib_converters()
plt.rcParams["font.family"] = 'AppleGothic'
plt.rcParams["font.size"] = 20
plt.rcParams["figure.figsize"] = (14,4)
matplotlib.rcParams['axes.unicode_minus'] = False


news_db = pd.read_csv('news_title_fixed.csv')

stock_info_path = "stock_info_0615.csv"
stock_data = pd.read_csv(stock_info_path, index_col='Unnamed: 0')

# %%
def get_top_topic_news(code1, code2, news_db, stock_info_db, N, print_result=False):

    name1 = stock_info_db[stock_info_db['short_code']==code1]['korean_name'].values[0]
    name2 = stock_info_db[stock_info_db['short_code']==code2]['korean_name'].values[0]

    name1 = name1.lower()
    name2 = name2.lower()    
    
    stock_news = news_db[news_db['GICODE']==code1].reset_index(drop=True)

    # text array format 변경 #
    documents = t_helper.pd_foramt_to_documents(stock_news,0,1)

    # Count-vectorizer 로 적용 #
    tf = CountVectorizer(max_features = 50, ngram_range=(3,3))
    tf_sp = tf.fit_transform(documents)

    # 점수별로 word 리스트 만들기
    tf_dict = tf.get_feature_names()
    data_array = tf_sp.toarray()

    # 이 기사들로 한해서 word score (tf_based) 로 진행
    data_array_select = data_array

    count_scores = np.sum(data_array_select,axis=0)
    count_scores_sort = np.sort(count_scores)[::-1]

    score_list = []
    for i in np.unique(count_scores_sort):
        index_list = np.argwhere(count_scores==i)
        for index in index_list:
            score_list.append((i,tf_dict[index[0]]))

    top_key_words = [word for i, word in score_list[::-1]]

    for word, score in zip(top_key_words, count_scores_sort):
        if print_result:
            print('%s : %s'%(word,score))

        ## 리셋한번 시켜주기
        stock_news['counting'] = 0

        index = np.argwhere(np.array(tf_dict)==word)[0][0]

        stock_news['counting'] = data_array[:,index]

        selected_news =stock_news[stock_news['counting']>0]

        if print_result:
            print(selected_news[:N]['TITLE'])
            print('\n\n')

    return top_key_words, count_scores_sort

# %%
key_words, news_info = get_top_topic_news('A021240', 'A251270', news_db, stock_data,5,True)
# Out:
# 넷마블 웅진코웨이 인수 : 24
# 787    [특징주]와이제이엠게임즈, 넷마블 웅진코웨이 인수 후보자 급부상에 강세
# 788                 곳간 2.4조 넷마블, 웅진코웨이 인수 가능성↑
# 789          넷마블 웅진코웨이 인수 참전 소식에…웅진 웅진씽크빅 `대박`
# 794       [단독] 넷마블, 웅진코웨이 품는다…14일 인수 우선협상자로 선정
# 800                  넷마블, 웅진코웨이 인수 우선협상대상자로 선정
# Name: TITLE, dtype: object
#
#
#
# 어워드 연속 수상 : 18
# 171     코웨이, 獨 'iF 디자인 어워드' 12년 연속 수상
# 172         코웨이, iF 디자인 어워드 12년 연속 수상
# 229    웅진코웨이, ‘레드닷 디자인 어워드’ 13년 연속 수상
# 230    웅진코웨이, '레드닷 디자인 어워드' 13년 연속 수상
# 232    웅진코웨이, `레드닷 디자인 어워드` 13년 연속 수상
# Name: TITLE, dtype: object
#
#
#
# 디자인 어워드 연속 : 18
# 171     코웨이, 獨 'iF 디자인 어워드' 12년 연속 수상
# 172         코웨이, iF 디자인 어워드 12년 연속 수상
# 229    웅진코웨이, ‘레드닷 디자인 어워드’ 13년 연속 수상
# 230    웅진코웨이, '레드닷 디자인 어워드' 13년 연속 수상
# 232    웅진코웨이, `레드닷 디자인 어워드` 13년 연속 수상
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 교체 매트리스 : 12
# 661             웅진코웨이, '탑퍼교체 매트리스 하이브리드3' 출시
# 662             웅진코웨이, '탑퍼교체 매트리스 하이브리드3' 출시
# 663               웅진코웨이, 탑퍼교체 매트리스 하이브리드3 출시
# 664             웅진코웨이, 탑퍼교체 매트리스 '하이브리드3' 출시
# 666    <신제품ㆍ신기술>웅진코웨이, ‘탑퍼교체 매트리스 하이브리드3’ 출시
# Name: TITLE, dtype: object
#
#
#
# 웅진 코웨이 매각 : 12
# 453                   웅진, 코웨이 매각 추진
# 454       웅진, 코웨이 매각 결정…"시장 충격 최소화"
# 457    웅진, 코웨이 매각 추진…재무리스크 '발목'(상보)
# 463      [특징주]웅진, 코웨이 매각 소식에 관련주 희비
# 469        [특징주] 웅진, 코웨이 재매각 결정에 약세
# Name: TITLE, dtype: object
#
#
#
# 제품 기술 웅진코웨이 : 11
# 292    [신제품·신기술] 웅진코웨이, 좁은 공간 대용량 ‘슬림 스탠드 정수기’
# 361      [신제품·신기술] 웅진코웨이, 빅데이터 활용 ‘워터맵 서비스’ 출시
# 398    [신제품·신기술] 웅진코웨이, 4중겹 ‘컴팩트 메모리폼 매트리스’ 출시
# 415          [신제품·신기술] 웅진코웨이, ‘나노직수 정수기’ 추가 출시
# 519       <신제품ㆍ신기술>웅진코웨이, 초미세먼지 두 번 걸러주는 공기청정기
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 시루직수 정수기 : 11
# 399                 웅진코웨이, '시루직수 정수기' 국립중앙과학관 전시
# 400    웅진코웨이, ‘시루직수 정수기’ 국립중앙과학관 전시.."환경가전기업 ...
# 401                 웅진코웨이 ‘시루직수 정수기’, 국립중앙과학관 전시
# 403                             웅진코웨이 `시루직수 정수기`
# 404          웅진코웨이 '시루직수 정수기' 국립중앙과학관 전시… 기술력 인정
# Name: TITLE, dtype: object
#
#
#
# 벽걸이 겸용 공기청정기 : 10
# 514           웅진코웨이 "미세먼지 두 번 걸러"…벽걸이 겸용 '공기청정기'
# 517                       웅진코웨이, 벽걸이 겸용 공기청정기 출시
# 518    웅진코웨이, 초미세 더블 집진필터 탑재한 `벽걸이 겸용 공기청정기` ...
# 883           웅진코웨이, 대형 벽걸이 겸용 공기청정기 AP-3519A 출시
# 888                         코웨이, 벽걸이 겸용 공기청정기 출시
# Name: TITLE, dtype: object
#
#
#
# 넷마블 코웨이 인수 : 9
# 813       [특징주]웅진코웨이·넷마블, 코웨이 인수 소식에 나란히↑
# 837         [컨콜] 넷마블 "코웨이 인수는 자체 현금으로 진행"
# 843           넷마블의 코웨이 인수, 한투증권 IB '전화위복'
# 854    넷마블, 코웨이 인수 시너지 불확실…사업 방향성 확인해야-신영
# 890       넷마블, 코웨이 인수 소식에 외국인 엑소더스 가속화…왜?
# Name: TITLE, dtype: object
#
#
#
# 웅진씽크빅 웅진코웨이 지분 : 8
# 465          웅진씽크빅, 웅진코웨이 지분 매각설 관련 조회공시 요구
# 468     거래소, 웅진씽크빅에 웅진코웨이 지분 매각설 관련 조회공시 요구
# 471             [조회공시]웅진씽크빅, 웅진코웨이 지분 매각 관련
# 485                 웅진씽크빅 "웅진코웨이 지분 매각 검토중"
# 488    웅진씽크빅 “웅진코웨이 지분 매각 검토 중..결정된 사항은 없어”
# Name: TITLE, dtype: object
#
#
#
# 코웨이 관리 공기청정기 : 7
# 1095                   코웨이, '자가관리형 공기청정기 카트리지' 출시
# 1109         <신제품ㆍ신기술>코웨이, ‘자가관리형 공기청정기 카트리지’ 내놓아
# 1130    코웨이 자가관리형 공기청정기 등 3개 제품 iF 수상···"13년 연...
# 1181          코웨이, 자가관리 공기청정기 구매 고객에게 필터 무상 추가 증정
# 1184         코웨이, '자가관리 공기청정기' 프로모션…"필터 최대 3년 무상"
# Name: TITLE, dtype: object
#
#
#
# 컴팩트 메모리폼 매트리스 : 7
# 387       4중 레이어로 편안한 숙면 웅진코웨이, 컴팩트 메모리폼 매트리스 ...
# 388                     웅진코웨이, ‘컴팩트 메모리폼 매트리스’ 출시
# 390          웅진코웨이, '컴팩트 메모리폼 매트리스 출시…"4중 레이어 숙면"
# 392    웅진코웨이, 4중 레이어 구조 적용 ‘컴팩트 메모리폼 매트리스’로 시장...
# 398       [신제품·신기술] 웅진코웨이, 4중겹 ‘컴팩트 메모리폼 매트리스’ 출시
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 지분 매각 : 7
# 471               [조회공시]웅진씽크빅, 웅진코웨이 지분 매각 관련
# 485                   웅진씽크빅 "웅진코웨이 지분 매각 검토중"
# 486    웅진씽크빅 "재무 안정성 확보 목적으로 웅진코웨이 지분 매각 검토중"
# 488      웅진씽크빅 “웅진코웨이 지분 매각 검토 중..결정된 사항은 없어”
# 550                   웅진씽크빅 "웅진코웨이 지분 매각 검토중"
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 이상 상승 : 7
# 473    '웅진코웨이' 5% 이상 상승, 2019.1Q, 매출액 7,093억(+...
# 528    '웅진코웨이' 5% 이상 상승, 주가 60일 이평선 상회, 단기·중기 ...
# 535       '웅진코웨이' 5% 이상 상승, 주가 상승 중, 단기간 골든크로스 형성
# 584                '웅진코웨이' 5% 이상 상승, 전일 기관 대량 순매수
# 595          '웅진코웨이' 5% 이상 상승, 단기·중기 이평선 정배열로 상승세
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 분기 영업익 : 7
# 332    웅진코웨이, 1분기 영업익 1352억 ‘역대 최대’… 렌털판매 상승세
# 333      웅진코웨이, 1분기 영업익 1352억원…렌털판매 증가로 역대 최대
# 563          웅진코웨이, 2분기 영업익 1382억…전년 대비 6.9%↑
# 564      [공시]웅진코웨이, 2·4분기 영업익 1382억…전년比 6.9%↑
# 566            웅진코웨이, 2분기 영업익 1382억…전년비 6.9%↑
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 넷마블 인수 : 7
# 803       [클릭 e종목]"웅진코웨이, 넷마블이 인수했을 때 시너지 기대"
# 804                 웅진코웨이, 넷마블이 인수할 경우 가장 긍정적
# 807     웅진코웨이, 넷마블에 인수되면 공격적인 구조조정 우려 제한적-IBK
# 810    [Hot-Line] "웅진코웨이, 넷마블이 인수할 경우 가장 긍정적"
# 865       웅진코웨이, 넷마블 인수에 부정적 영향 없을 것...목표주가 ↑
# Name: TITLE, dtype: object
#
#
#
# 구매안심지수 정수기 비데 : 7
# 256            웅진코웨이, ‘한국산업 구매안심지수’ 정수기·비데 1위
# 257        웅진코웨이, 마케팅협회 ‘구매안심지수’ 정수기·비데 부문 1위
# 258        웅진코웨이, '한국산업의 구매안심지수' 정수기·비데 부문 1위
# 259        웅진코웨이, '한국산업의 구매안심지수' 정수기·비데 부문 1위
# 1288    코웨이, '2020 한국산업의 구매안심지수' 정수기·비데 부문 1위
# Name: TITLE, dtype: object
#
#
#
# 교체 매트리스 하이브리드 : 7
# 661               웅진코웨이, '탑퍼교체 매트리스 하이브리드3' 출시
# 662               웅진코웨이, '탑퍼교체 매트리스 하이브리드3' 출시
# 663                 웅진코웨이, 탑퍼교체 매트리스 하이브리드3 출시
# 664               웅진코웨이, 탑퍼교체 매트리스 '하이브리드3' 출시
# 665    웅진코웨이, 품질·안전성 뛰어난 '탑퍼교체 매트리스 하이브리드3' 출시
# Name: TITLE, dtype: object
#
#
#
# 겸용 공기청정기 출시 : 7
# 517            웅진코웨이, 벽걸이 겸용 공기청정기 출시
# 887        웅진코웨이, 벽걸이·스탠드 겸용 공기청정기 출시
# 888              코웨이, 벽걸이 겸용 공기청정기 출시
# 889               코웨이,벽걸이 겸용 공기청정기 출시
# 1292    코웨이, 2020년형 '벽걸이 겸용 공기청정기' 출시
# Name: TITLE, dtype: object
#
#
#
# 코웨이 임직원 자녀 : 6
# 123          코웨이, 임직원 자녀 초청 ‘과학캠프’ 개최
# 124      코웨이, 임직원 자녀 초청 '코웨이 과학캠프' 진행
# 125     코웨이, 임직원 자녀와 함께 '코웨이 과학캠프' 열어
# 126    코웨이 임직원 자녀 '과학캠프'…"가족친화적 기업문화"
# 127            코웨이, 임직원 자녀 초정 과학캠프 진행
# Name: TITLE, dtype: object
#
#
#
# 코웨이 시루직수 정수기 : 6
# 81      [2019 아시아소비자대상] 코웨이 '시루직수 정수기'…미세 이온물질 ...
# 1212               전기레인지 증정…코웨이, '한뼘 시루직수 정수기' 이벤트
# 1213               코웨이, ‘한뼘 시루직수 정수기’ 구매 인증 이벤트 진행
# 1214                  코웨이, '한뼘 시루직수 정수기' 구매 인증 이벤트
# 1215                   코웨이, '한뼘 시루직수 정수기' 구매인증 이벤트
# Name: TITLE, dtype: object
#
#
#
# 코웨이 if 디자인 : 6
# 171       코웨이, 獨 'iF 디자인 어워드' 12년 연속 수상
# 172           코웨이, iF 디자인 어워드 12년 연속 수상
# 1129        코웨이, ‘iF 디자인 어워드’ 13년 연속 수상
# 1131            코웨이, 'iF 디자인상' 3개 부문 수상
# 1132    코웨이, 獨 'iF 디자인 어워드' 13년 연속 디자인상
# Name: TITLE, dtype: object
#
#
#
# 지분 매각 검토 : 6
# 485                   웅진씽크빅 "웅진코웨이 지분 매각 검토중"
# 486    웅진씽크빅 "재무 안정성 확보 목적으로 웅진코웨이 지분 매각 검토중"
# 488      웅진씽크빅 “웅진코웨이 지분 매각 검토 중..결정된 사항은 없어”
# 550                   웅진씽크빅 "웅진코웨이 지분 매각 검토중"
# 551                 웅진씽크빅, “웅진코웨이 지분 매각 검토 중”
# Name: TITLE, dtype: object
#
#
#
# 제품 기술 코웨이 : 6
# 88           [신제품·신기술] 코웨이, CES 혁신상 ‘한방온혈 안마의자’ 출시
# 1088           <신제품ㆍ신기술>코웨이, 한국인 체형용 ‘모션베드 프레임’ 출시
# 1109          <신제품ㆍ신기술>코웨이, ‘자가관리형 공기청정기 카트리지’ 내놓아
# 1216             <신제품ㆍ신기술>코웨이, 고화력 ‘인덕션 전기레인지’ 선보여
# 1231    <신제품ㆍ신기술>코웨이, 의류관리+건조 ‘사계절 의류청정기 싱글케어’ ...
# Name: TITLE, dtype: object
#
#
#
# 정수기 비데 부문 : 6
# 257        웅진코웨이, 마케팅협회 ‘구매안심지수’ 정수기·비데 부문 1위
# 258        웅진코웨이, '한국산업의 구매안심지수' 정수기·비데 부문 1위
# 259        웅진코웨이, '한국산업의 구매안심지수' 정수기·비데 부문 1위
# 731      웅진코웨이, ‘브랜드고객만족도’ 정수기·비데 부문 3년 연속 1위
# 1288    코웨이, '2020 한국산업의 구매안심지수' 정수기·비데 부문 1위
# Name: TITLE, dtype: object
#
#
#
# 임직원 자녀 초청 : 6
# 123                      코웨이, 임직원 자녀 초청 ‘과학캠프’ 개최
# 124                  코웨이, 임직원 자녀 초청 '코웨이 과학캠프' 진행
# 217    [청년이 미래다] 코웨이, 임직원 자녀 초청 `과학캠프` 호응…`Wi ...
# 601                      웅진코웨이, 임직원 자녀 초청 과학캠프 진행
# 603                  웅진코웨이, 임직원 자녀 40여명 초청 '과학캠프'
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 처분 결정 : 6
# 325        웅진코웨이, 자사주 3만160주 처분 결정
# 328     IR-웅진코웨이, 자사주 3만160주 처분 결정
# 329        웅진코웨이, 자사주 3만160주 처분 결정
# 1097    [공시] 웅진코웨이, 자사주 6만여주 처분 결정
# 1098      웅진코웨이, 자사주 6만7900주 처분 결정
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 스타일케어 리모트 : 6
# 677             웅진코웨이, '스타일케어 리모트 비데' 출시
# 678             웅진코웨이, '스타일케어 리모트 비데' 출시
# 679    웅진코웨이, 스타일케어 리모트 비데 출시…무선 리모컨 디자인
# 680             웅진코웨이, '스타일케어 리모트 비데' 출시
# 681      새로나왔어요/웅진코웨이, '스타일케어 리모트 비데' 출시
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 매각 입찰 : 6
# 723         [마켓인사이트] 웅진코웨이 매각 본입찰 다음달로 또 연기
# 726                웅진코웨이 매각 본입찰 다음달 10일로 연기
# 728          [특징주]웅진코웨이, 매각 본입찰 10월로 연기에 하락
# 762    [단독][마켓인사이트] 웅진코웨이 매각 본입찰에 넷마블 깜짝 등장
# 771              웅진코웨이 매각 본입찰…게임사 넷마블 전격 참여
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 대용량 공기청정기 : 6
# 637    웅진코웨이, 대용량 공기청정기 판매량 전년 대비 150% 증가
# 639           웅진코웨이, 대용량 공기청정기 판매 150% 증가
# 640        웅진코웨이, 대용량 공기청정기 판매량 150% '껑충'
# 641       웅진코웨이, 대용량 공기청정기 판매량 전년比 '2.5배'
# 642           웅진코웨이, 대용량 공기청정기 판매 150% 증가
# Name: TITLE, dtype: object
#
#
#
# 웅진 웅진코웨이 매각 : 6
# 464            [특징주] 웅진, 웅진코웨이 재매각 결정에 급락
# 466        [특징주]웅진, 웅진코웨이 재매각 소식에 동반 '약세'
# 494           웅진, 웅진코웨이 재매각 결정에 급락…장중 신저가
# 815           [특징주] 웅진, 웅진코웨이 매각 기대감에 상한가
# 861    [특징주]웅진, 웅진코웨이 매각 기대감에 3거래일 연속 상승세
# Name: TITLE, dtype: object
#
#
#
# 슬림 스탠드 정수기 : 6
# 286                웅진코웨이, '가로 26cm' 슬림 스탠드 정수기 출시
# 287     웅진코웨이, 사이즈 줄이고 탱크 용량 키운 ‘슬림 스탠드 정수기' 선...
# 288    웅진코웨이, 사이즈 줄이고 탱크 용량 키운 ‘슬림 스탠드 정수기' 선보...
# 289                        웅진코웨이, '슬림 스탠드 정수기' 출시
# 290                        웅진코웨이, ‘슬림 스탠드 정수기’ 출시
# Name: TITLE, dtype: object
#
#
#
# 스타일케어 리모트 비데 : 6
# 677             웅진코웨이, '스타일케어 리모트 비데' 출시
# 678             웅진코웨이, '스타일케어 리모트 비데' 출시
# 679    웅진코웨이, 스타일케어 리모트 비데 출시…무선 리모컨 디자인
# 680             웅진코웨이, '스타일케어 리모트 비데' 출시
# 681      새로나왔어요/웅진코웨이, '스타일케어 리모트 비데' 출시
# Name: TITLE, dtype: object
#
#
#
# 사계절 의류청정기 케어 : 6
# 1224                      코웨이, 사계절 의류청정기 '싱글케어' 출시
# 1225                      코웨이, '사계절 의류청정기 싱글케어' 출시
# 1226    코웨이, 의류관리에 건조기능까지 갖춘 '사계절 의류청정기 싱글케어' 출...
# 1228                      코웨이, '사계절 의류청정기 싱글케어' 출시
# 1230                      코웨이, `사계절 의류청정기 싱글케어` 출시
# Name: TITLE, dtype: object
#
#
#
# 물맛 지수 개발 : 6
# 1169            코웨이, 업계 최초 '물맛 지수' 개발
# 1170    코웨이, '물맛 지수' 개발…"더 맛있고 깨끗한 물"
# 1173            코웨이, 업계 최초 ‘물맛 지수’ 개발
# 1176           코웨이, 업계 최초로 ‘물맛 지수’ 개발
# 1177       생활가전기업 코웨이, 정수기 `물맛 지수` 개발
# Name: TITLE, dtype: object
#
#
#
# 메모리폼 매트리스 출시 : 6
# 388                   웅진코웨이, ‘컴팩트 메모리폼 매트리스’ 출시
# 389               웅진코웨이, 메모리폼 매트리스 출시…4중 레이어 구조
# 390        웅진코웨이, '컴팩트 메모리폼 매트리스 출시…"4중 레이어 숙면"
# 398     [신제품·신기술] 웅진코웨이, 4중겹 ‘컴팩트 메모리폼 매트리스’ 출시
# 1248             코웨이, 탄탄함 강화 '컴팩트 메모리폼 매트리스' 출시
# Name: TITLE, dtype: object
#
#
#
# 매트리스 하이브리드 출시 : 6
# 661               웅진코웨이, '탑퍼교체 매트리스 하이브리드3' 출시
# 662               웅진코웨이, '탑퍼교체 매트리스 하이브리드3' 출시
# 663                 웅진코웨이, 탑퍼교체 매트리스 하이브리드3 출시
# 664               웅진코웨이, 탑퍼교체 매트리스 '하이브리드3' 출시
# 665    웅진코웨이, 품질·안전성 뛰어난 '탑퍼교체 매트리스 하이브리드3' 출시
# Name: TITLE, dtype: object
#
#
#
# 리모트 비데 출시 : 6
# 677             웅진코웨이, '스타일케어 리모트 비데' 출시
# 678             웅진코웨이, '스타일케어 리모트 비데' 출시
# 679    웅진코웨이, 스타일케어 리모트 비데 출시…무선 리모컨 디자인
# 680             웅진코웨이, '스타일케어 리모트 비데' 출시
# 681      새로나왔어요/웅진코웨이, '스타일케어 리모트 비데' 출시
# Name: TITLE, dtype: object
#
#
#
# 교체 매트리스 프라임 : 6
# 713              웅진코웨이, 탑퍼교체 매트리스 '프라임 라지킹' 출시
# 714              웅진코웨이, '탑퍼교체 매트리스 프라임 라지킹' 출시
# 715    넓고 쾌적한 수면 보장 웅진코웨이, 탑퍼교체 매트리스 프라임 라지...
# 716              웅진코웨이, '탑퍼교체 매트리스 프라임 라지킹' 출시
# 717              웅진코웨이, '탑퍼교체 매트리스 프라임 라지킹' 출시
# Name: TITLE, dtype: object
#
#
#
# sk네트웍스 웅진코웨이 인수 : 6
# 532    [Hot-Line] “SK네트웍스, 웅진코웨이 인수 결단이 필요한 시점...
# 533                    미래대우, “SK네트웍스가 웅진코웨이 인수하라”
# 534                     미래대우 “SK네트웍스가 웅진코웨이 인수하라”
# 753                        SK네트웍스, 웅진코웨이 인수 포기 왜?
# 756                   SK네트웍스 "웅진코웨이 인수 안한다" 공식 발표
# Name: TITLE, dtype: object
#
#
#
# if 디자인 어워드 : 6
# 170         코웨이, 12년 연속 ‘iF 디자인 어워드' 수상
# 171       코웨이, 獨 'iF 디자인 어워드' 12년 연속 수상
# 172           코웨이, iF 디자인 어워드 12년 연속 수상
# 1129        코웨이, ‘iF 디자인 어워드’ 13년 연속 수상
# 1132    코웨이, 獨 'iF 디자인 어워드' 13년 연속 디자인상
# Name: TITLE, dtype: object
#
#
#
# 프라임 라지킹 출시 : 5
# 713    웅진코웨이, 탑퍼교체 매트리스 '프라임 라지킹' 출시
# 714    웅진코웨이, '탑퍼교체 매트리스 프라임 라지킹' 출시
# 716    웅진코웨이, '탑퍼교체 매트리스 프라임 라지킹' 출시
# 717    웅진코웨이, '탑퍼교체 매트리스 프라임 라지킹' 출시
# 719     웅진코웨이 '탑퍼교체 매트리스 프라임 라지킹' 출시
# Name: TITLE, dtype: object
#
#
#
# 코웨이 사계절 의류청정기 : 5
# 1203    '코로나19 확산' 코웨이 사계절 의류청정기 더블케어 '관심'
# 1224              코웨이, 사계절 의류청정기 '싱글케어' 출시
# 1225              코웨이, '사계절 의류청정기 싱글케어' 출시
# 1228              코웨이, '사계절 의류청정기 싱글케어' 출시
# 1230              코웨이, `사계절 의류청정기 싱글케어` 출시
# Name: TITLE, dtype: object
#
#
#
# 자녀 초청 과학캠프 : 5
# 123                      코웨이, 임직원 자녀 초청 ‘과학캠프’ 개최
# 217    [청년이 미래다] 코웨이, 임직원 자녀 초청 `과학캠프` 호응…`Wi ...
# 601                      웅진코웨이, 임직원 자녀 초청 과학캠프 진행
# 603                  웅진코웨이, 임직원 자녀 40여명 초청 '과학캠프'
# 604                      웅진코웨이, 임직원 자녀 초청 과학캠프 진행
# Name: TITLE, dtype: object
#
#
#
# 인덕션 전기레인지 출시 : 5
# 1209           코웨이, 프리미엄 '인덕션 전기레인지' 출시
# 1210    코웨이, 성능·편의성 다 잡은 '인덕션 전기레인지' 출시
# 1211         코웨이, 화력 강화한 '인덕션 전기레인지' 출시
# 1273       코웨이, 인덕션 전기레인지 출시 기념 프로모션 진행
# 1277    코웨이, '인덕션 전기레인지' 출시…"렌털료 할인 혜택"
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 임직원 자녀 : 5
# 601        웅진코웨이, 임직원 자녀 초청 과학캠프 진행
# 602      웅진코웨이, 임직원 자녀 위한 '과학캠프' 진행
# 603    웅진코웨이, 임직원 자녀 40여명 초청 '과학캠프'
# 604        웅진코웨이, 임직원 자녀 초청 과학캠프 진행
# 610      물맛 알려주마…웅진코웨이, 임직원 자녀 과학캠프
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 사계절 의류청정기 : 5
# 379                    웅진코웨이, ‘사계절 의류청정기 더블케어’ 출시
# 381    '이제는 의류 건조까지 척척' 웅진코웨이, 사계절 의류청정기 더블케어 ...
# 382     '이제는 의류 건조까지 척척' 웅진코웨이, 사계절 의류청정기 더블케어...
# 385               의류 관리·건조·냄새제거까지…웅진코웨이 사계절 의류청정기
# 745                웅진코웨이, 사계절 '의류청정기 더블케어'로 시장 선도
# Name: TITLE, dtype: object
#
#
#
# 웅진코웨이 벽걸이 겸용 : 5
# 438    웅진코웨이 '벽걸이 겸용 공청기', 17년 연속 신기술 혁신상 수상
# 517                   웅진코웨이, 벽걸이 겸용 공기청정기 출시
# 884              웅진코웨이, '벽걸이 겸용' 대형 공기청정기 출시
# 886               웅진코웨이, 벽걸이 겸용 대용량 공기청정기 출시
# 895          <신제품ㆍ신기술>웅진코웨이, 벽걸이 겸용 대형 공기청정기
# Name: TITLE, dtype: object
#
#
#
# 단기 중기 이평선 : 5
# 181    '코웨이' 52주 신고가 경신, 전형적인 상승세, 단기·중기 이평선 정...
# 184    '코웨이' 52주 신고가 경신, 전형적인 상승세, 단기·중기 이평선 정...
# 197    '코웨이' 52주 신고가 경신, 전형적인 상승세, 단기·중기 이평선 정...
# 240    '코웨이' 52주 신고가 경신, 전형적인 상승세, 단기·중기 이평선 정...
# 595          '웅진코웨이' 5% 이상 상승, 단기·중기 이평선 정배열로 상승세
# Name: TITLE, dtype: object
#
#
#
# idea 디자인 어워드 : 5
# 651    웅진코웨이, 'IDEA 디자인 어워드' 10년 연속 수상
# 653      웅진코웨이, IDEA 디자인 어워드 10년 연속 수상
# 654    웅진코웨이, 'IDEA 디자인 어워드' 10년 연속 수상
# 656      웅진코웨이, IDEA 디자인 어워드 10년 연속 수상
# 657      웅진코웨이, IDEA 디자인 어워드 10년 연속 수상
# Name: TITLE, dtype: object

# %% [markdown]
# 현재 모델의 단점 / 보완해야될 사항 : 단어 / 문장간의 유사도를 측정할 수 없다. (Word2Vec / Doc2Vec 을 통해서 문장/단어/특정 토픽등을 벡터화 시켜야함)
#
# -> 참고로 위의 모델의 경우
#
# (어워드 연속 수상 / 디자인 어워드 연속) 이 두개가 같다는것을 인식하지 못한다.
#
# 단어의 경우 임베딩을 통해서 유사도를 측정하기 쉽지만, 이게 단어가 아닌 문장으로 넘어갈시에 다른 기법이 필요하다.
#
#
# 예시 : 비데 / 의류청정기 등은 모두 제품인데, 위의 경우 이러한 정보를 알 수가 없다.

# %% [markdown]
# # 기능 2 : 뉴스 이외의 분야에서 데이터 추출하기
#
#
#
# ![alt text](dart_example.png "DART 기업 공시")
#
# DART 기업 분기별 보고서의 '사업의 내용' 항목을 통해서 각 기업들의 특징등을 추출해보았다.

# %%
import pickle

# Getting back the objects:
with open('dart_text.pkl','rb') as f: 
    docs = pickle.load(f)

# %%
print(docs[0][:1000])
# Out:
#  II. 사업의 내용 1. 사업의 개요 가. 사업부문별 현황 당사는 본사를 거점으로 한국 및 CE, IM 부문 산하 해외 9개 지역총괄과 DS 부문 산하 해외 5개 지역총괄의 생산ㆍ판매법인, Harman 산하 종속기업 등 244개의 종속기업으로 구성된 글로벌 전자 기업입니다. 사업군별로 보면 Set사업에서는 TV를 비롯하여 모니터, 냉장고, 세탁기 등을 생산ㆍ판매하는 CE 부문과 스마트폰 등 HHP, 네트워크시스템, 컴퓨터 등을 생산ㆍ판매하는 IM 부문이 있습니다. 부품사업에서는 DRAM, NAND Flash, 모바일AP 등의 제품을 생산ㆍ판매하고 있는 반도체 사업과 모바일ㆍTVㆍ모니터ㆍ노트북 PC용 등의 OLED 및 TFT-LCD 디스플레이 패널을 생산ㆍ판매하고 있는 DP 사업의 DS 부문으로 구성되어 있습니다. 또한, 2017년 중 인수한 Harman 부문에서 디지털 콕핏, 텔레메틱스, 스피커 등을 생산ㆍ판매하고 있습니다.   [부문별 주요 제품] 부문 주요 제품 CE 부문  TV, 모니터, 냉장고, 세탁기, 에어컨 등 IM 부문  HHP, 네트워크시스템, 컴퓨터 등 DS부문 반도체 사업  DRAM, NAND Flash, 모바일AP 등 DP 사업  OLED 스마트폰 패널, LCD TV 패널, 모니터 패널 등 Harman 부문  디지털 콕핏, 텔레메틱스, 스피커 등 지역별로 보면 국내에는 CE, IM 부문 및 반도체 사업을 총괄하는 본사와 28개의 종속기업이 사업을 운영하고 있습니다. 본사는 수원, 구미, 기흥, 화성, 평택, 광주사업장 등으로 구성되어 있으며, 국내 종속기업은 디스플레이 패널을 생산하는 삼성디스플레이㈜와 국내 대리점 판매를 전담하는 삼성전자판매㈜, 제품의 서비스를 담당하는 삼성전자서비스㈜ 및 제품의 운송을 담당하는 삼성전자로지텍㈜ 등 총 28개의 비상장 종속기업으로 구성되어 있습니다.   해외는 미주, 유럽, 아시아, 아프리카 등지에서 생산, 판매, 연구활동을 담당하는 216개의 해외 종속기업이 운영되고 있습니다. 미주는 TV, HHP 등

# %%
Documents = []

## 형태소분석화 시키기
for paragraph in docs:

    # 문서본문을 형태소분석 시키기
    word_list = t_helper.article_2_word(paragraph)

    words = ''
    for word in word_list:
        words += word
        words += ' '


    # 문서제목을 형태소분석 시키기
    if words =='':
        continue
    Documents.append(words[:-1])


# TF-IDF 실행 : 단어 300개 선택

# max_df : max_document frequency
# min_df : min_document frequency
tfidf = TfidfVectorizer(max_features = 300, max_df=0.3, min_df=1,ngram_range = (1, 3))
A_tfidf_sp = tfidf.fit_transform(Documents)

tfidf_dict = tfidf.get_feature_names()
data_array = A_tfidf_sp.toarray()

count_scores = np.sum(data_array,axis=0)
count_scores_sort = np.sort(count_scores)

score_list = []
for i in np.unique(count_scores_sort):
    index_list = np.argwhere(count_scores==i)
    for index in index_list:
        score_list.append((i,tfidf_dict[index[0]]))

# %% [markdown]
# ## 결과 Visualization 1 (키워드 -> 회사 매치)

# %%
for i, word in enumerate(tfidf_dict):
    print(word)
    for j, pt in enumerate(data_array[:,i]):
        if pt>0.2:
            print('%s : %.5f'%(stock_data['korean_name'][j],pt))
            
    print('\n  ')
# Out:
# ai
# NAVER : 0.30085
# SK텔레콤 : 0.47080
# 삼성에스디에스 : 0.35213
# KT : 0.26164
# 한화시스템 : 0.58108
# 현대오토에버 : 0.23824
# 롯데정보통신 : 0.31009
#
#
# al
# 대한전선 : 0.23270
# 동원시스템즈 : 0.31725
#
#
# buy
# S-Oil : 0.62945
# 고려아연 : 0.95755
# LS ELECTRIC : 0.50548
# SK케미칼 : 0.24531
# SK가스 : 0.33678
#
#
# cd
# NICE : 0.32480
#
#
# cds
# 하나금융지주 : 0.51928
#
#
# cell
# 파미셀 : 0.37754
# 차바이오텍 : 0.28286
# 두산 : 0.26283
#
#
# chemical
# 롯데케미칼 : 0.49732
# 네패스 : 0.33532
#
#
# china
# 삼성전기 : 0.27603
# 삼성전기 : 0.27603
# CJ제일제당 : 0.30535
# 실리콘웍스 : 0.20761
#
#
# cj
# CJ제일제당 : 0.87615
# CJ대한통운 : 0.96527
#
#
# cln
# 삼성증권 : 0.94454
# 메리츠증권 : 0.25026
# 메리츠금융지주 : 0.67642
#
#
# cny
# 동원F&B : 0.21697
#
#
# company
# 삼성엔지니어링 : 0.28407
# 휠라홀딩스 : 0.38559
# 한화에어로스페이스 : 0.25013
#
#
# fda
# 휴젤 : 0.20989
# 네이처셀 : 0.26180
#
#
# for
# 한올바이오파마 : 0.56827
#
#
# fy
# 삼성화재 : 0.26554
# 한국금융지주 : 0.95990
#
#
# gan
# RFHIC : 0.97438
#
#
# gb
# 삼성전자 : 0.45105
# SK하이닉스 : 0.59842
# LG : 0.40298
# KT : 0.24502
# LG유플러스 : 0.72741
#
#
# international
# 오리온 : 0.31392
# 포스코인터내셔널 : 0.49118
#
#
# iso
# 삼성전기 : 0.31546
# 삼성전기 : 0.31546
# 금호석유 : 0.39069
# OCI : 0.31643
# 동원F&B : 0.22933
#
#
# kr
# KCC : 0.34890
# 엔지켐생명과학 : 0.41796
# 녹십자랩셀 : 0.21757
#
#
# krw
# 한국전력 : 0.24051
# 삼성중공업 : 0.36710
# LG디스플레이 : 0.31260
# 한국가스공사 : 0.56148
# 삼성엔지니어링 : 0.38859
# 현대위아 : 0.45438
# 아이에스동서 : 0.26249
#
#
# lcd
# LG디스플레이 : 0.36798
# 에스에프에이 : 0.32015
# 동진쎄미켐 : 0.31246
# 이오테크닉스 : 0.26577
# 에스앤에스텍 : 0.51642
#
#
# led
# LG이노텍 : 0.41868
# 케이엠더블유 : 0.71493
# 티씨케이 : 0.31262
# 서울반도체 : 0.99571
# 서울바이오시스 : 0.99080
#
#
# lg
# LG화학 : 0.50686
# LG : 0.70275
# LG전자 : 0.83114
# LG하우시스 : 0.27253
#
#
# limited
# 제일기획 : 0.52767
# JYP Ent. : 0.24915
#
#
# llc
# 오리온 : 0.25766
# 에스원 : 0.20760
# 제일기획 : 0.21509
# 이노션 : 0.36558
#
#
# lng
# POSCO : 0.43179
# 삼성중공업 : 0.22774
# GS : 0.20827
# 대우조선해양 : 0.43750
# 한국가스공사 : 0.71915
# 팬오션 : 0.31830
# 포스코인터내셔널 : 0.20417
# 현대미포조선 : 0.29351
# SK가스 : 0.35074
# 하림지주 : 0.25559
#
#
# lotte
# 롯데케미칼 : 0.79740
# 롯데지주 : 0.74198
# 롯데쇼핑 : 0.45784
# 롯데제과 : 0.87622
#
#
# lte
# LG : 0.23871
# KT : 0.33309
# LG유플러스 : 0.40669
# LS : 0.22257
#
#
# mg
# 보령제약 : 0.91004
# 녹십자랩셀 : 0.46558
# CMG제약 : 0.92201
#
#
# mw
# 한국전력 : 0.39140
# GS : 0.45166
# 한전KPS : 0.39767
# 두산중공업 : 0.27262
# 두산 : 0.20293
#
#
# oled
# 삼성전자 : 0.25266
# 삼성SDI : 0.20197
# LG디스플레이 : 0.71606
# 에스에프에이 : 0.53070
# 이오테크닉스 : 0.21549
# 톱텍 : 0.44874
# 덕산네오룩스 : 0.87850
# 실리콘웍스 : 0.68931
# 에스앤에스텍 : 0.30062
#
#
# pc
# SK하이닉스 : 0.21558
# 삼성전기 : 0.26115
# 삼성전기 : 0.26115
# 오뚜기 : 0.37074
#
#
# service
# 한온시스템 : 0.75822
#
#
# sh
# 신한지주 : 0.27033
#
#
# sh trs
# 신한지주 : 0.31865
#
#
# sh trs 씨앗
# 신한지주 : 0.29933
#
#
# sk
# SK : 0.85667
# SK텔레콤 : 0.30788
# SK이노베이션 : 0.83222
# SK네트웍스 : 0.47980
# SK케미칼 : 0.52159
# SK가스 : 0.41026
#
#
# ton
# 오리온 : 0.70414
# 현대제철 : 0.29931
# 오뚜기 : 0.20680
# 농심 : 0.24852
# 한솔케미칼 : 0.20850
# 아이에스동서 : 0.39129
# 오리온홀딩스 : 0.40980
# 태광산업 : 0.31250
# 대한전선 : 0.47632
# SPC삼립 : 0.81996
#
#
# trs
# 신한지주 : 0.20681
#
#
# trs 씨앗
# 신한지주 : 0.29933
#
#
# trs 씨앗 신한금융투자
# 신한지주 : 0.29933
#
#
# tv
# 삼성전자 : 0.58856
# LG전자 : 0.21870
# KT : 0.24529
# LG디스플레이 : 0.27801
# 제일기획 : 0.24679
# 롯데하이마트 : 0.27566
# 실리콘웍스 : 0.46834
#
#
# us
# 엔씨소프트 : 0.86132
# 유한양행 : 0.23068
# 신풍제약 : 0.59157
# 한화에어로스페이스 : 0.21764
# JW중외제약 : 0.21827
#
#
# usa
# 에이치엘비 : 0.23552
# 풀무원 : 0.23860
#
#
# usd eur
# 삼성엔지니어링 : 0.20651
# 금호석유 : 0.22274
# 동원F&B : 0.20919
# 락앤락 : 0.22740
#
#
# vietnam
# 에스원 : 0.26429
# 현대미포조선 : 0.20077
# 영풍 : 0.21452
#
#
# 가구
# 신세계 : 0.69937
# 한샘 : 0.71842
# 지누스 : 0.88804
# 현대그린푸드 : 0.47955
# 락앤락 : 0.34706
#
#
# 가맹점
# 삼성카드 : 0.28495
# GS리테일 : 0.43552
# BGF리테일 : 0.52355
# NHN한국사이버결제 : 0.37179
# JB금융지주 : 0.21443
# NICE : 0.67550
# 풀무원 : 0.41107
#
#
# 가스
# 한국가스공사 : 0.24280
# 삼성엔지니어링 : 0.22226
# 현대로템 : 0.37490
# 대한유화 : 0.59282
#
#
# 가입
#
#
# 가입대상
# 우리금융지주 : 0.48972
# 기업은행 : 0.95953
# BNK금융지주 : 0.52703
# JB금융지주 : 0.42398
#
#
# 가입자
# SK텔레콤 : 0.40825
# KT : 0.24619
# LG유플러스 : 0.28178
# 태광산업 : 0.51305
#
#
# 가전
# 현대제철 : 0.31534
# 쿠쿠홈시스 : 0.22357
# 롯데하이마트 : 0.35227
# 동국제강 : 0.36406
#
#
# 개발 진행
# NAVER : 0.35314
# 네패스 : 0.23081
#
#
# 건강기능식품
# SKC : 0.26556
# 녹십자 : 0.56956
# 헬릭스미스 : 0.30177
# 콜마비앤에이치 : 0.68442
# 빙그레 : 0.23065
# 서흥 : 0.68512
# 종근당홀딩스 : 0.24816
# 풀무원 : 0.56706
#
#
# 건설기계
# 현대중공업지주 : 0.59066
# 두산밥캣 : 0.78504
# 두산인프라코어 : 0.77361
# 두산중공업 : 0.68671
# 현대그린푸드 : 0.47557
# 두산 : 0.61185
#
#
# 건축
# KCC : 0.33167
# 롯데정밀화학 : 0.32659
#
#
# 검사
# 씨젠 : 0.53717
# 리노공업 : 0.20984
# 한전KPS : 0.29962
# 고영 : 0.68953
# 영원무역 : 0.27270
#
#
# 게임
# 카카오 : 0.49857
# 엔씨소프트 : 0.48727
# 넷마블 : 0.99770
# 펄어비스 : 0.28367
# NHN : 0.97598
# 더블유게임즈 : 0.95967
# 컴투스 : 0.98840
# GKL : 0.20947
# 웹젠 : 0.97137
#
#
# 경쟁제품
# 셀트리온 : 0.39539
# 셀트리온제약 : 0.24206
# 한미약품 : 0.30383
#
#
# 계약금
#
#
# 계약일
#
#
# 계약조건
# 삼성바이오로직스 : 0.21075
# 신풍제약 : 0.29885
# 종근당 : 0.24151
# 롯데정밀화학 : 0.38948
# 제일약품 : 0.23364
# 종근당홀딩스 : 0.26462
#
#
# 계약체결일
# 종근당 : 0.20382
# 제일약품 : 0.20163
#
#
# 공간
# 한샘 : 0.26636
# 에이치엘비생명과학 : 0.27051
# 이노션 : 0.30364
#
#
# 공구
# 대림산업 : 0.26358
#
#
# 공정가치 측정
# 에이치엘비 : 0.22258
# 롯데칠성 : 0.34174
#
#
# 관련논문
# 셀트리온 : 0.21472
# 셀트리온제약 : 0.24413
# 한미약품 : 0.24775
#
#
# 구성비
# 삼성카드 : 0.48677
# DB손해보험 : 0.20722
# 금호석유 : 0.58855
# 한샘 : 0.23881
# 신세계인터내셔날 : 0.39001
# DGB금융지주 : 0.20982
#
#
# 근무
# 미래에셋대우 : 0.22553
# 메리츠증권 : 0.25926
# 화승엔터프라이즈 : 0.21509
#
#
# 근무 상근
# 미래에셋대우 : 0.42253
# 메리츠증권 : 0.48001
#
#
# 금리
# DB손해보험 : 0.23742
#
#
# 금액 비율
# 삼성화재 : 0.21319
# 현대해상 : 0.74263
# 메리츠화재 : 0.56137
# 메리츠금융지주 : 0.20829
# 한화생명 : 0.55700
# DGB금융지주 : 0.45801
# 동원시스템즈 : 0.20782
#
#
# 금액 비중
# 삼성바이오로직스 : 0.33287
# 케이엠더블유 : 0.49216
# 이노션 : 0.24503
#
#
# 금액 수량
# 농심 : 0.29084
#
#
# 금액 수량 금액
# 농심 : 0.29390
#
#
# 금융투자
# 하나금융지주 : 0.50281
#
#
# 기계
#
#
# 기말잔액
# 삼성화재 : 0.78116
# DB손해보험 : 0.70683
# 현대해상 : 0.51830
# 메리츠화재 : 0.68564
# 한화생명 : 0.69161
# 코리안리 : 0.93940
#
#
# 기말장부
# 기아차 : 0.20537
# HMM : 0.25877
#
#
# 기술이전
# 제넥신 : 0.22822
# 에이비엘바이오 : 0.26779
# 레고켐바이오 : 0.78519
# 만도 : 0.31212
# 셀리버리 : 0.23092
#
#
# 기초장부
# 하이트진로 : 0.25804
# HMM : 0.21752
# NICE평가정보 : 0.25554
# 삼양식품 : 0.22354
# 동원산업 : 0.21135
#
#
# 기초장부 당기증감
# F&F : 0.20997
# NICE평가정보 : 0.31412
# 동원산업 : 0.25981
# 남선알미늄 : 0.20261
#
#
# 기초장부 당기증감 당기상각
# F&F : 0.22055
# NICE평가정보 : 0.32996
# 동원산업 : 0.27291
# 남선알미늄 : 0.21282
#
#
# 기타 소계
# 오리온 : 0.35176
# 오리온홀딩스 : 0.21836
#
#
# 기타사항
# 셀트리온 : 0.21177
# 셀트리온제약 : 0.25830
# 한미약품 : 0.31662
# 신풍제약 : 0.33067
# 종근당 : 0.35562
# SK케미칼 : 0.21190
# 삼천당제약 : 0.21106
# 동아에스티 : 0.35031
# 제일약품 : 0.43457
#
#
# 기획
# CJ ENM : 0.20678
# 이노션 : 0.56956
# 오리온홀딩스 : 0.49838
# 에코마케팅 : 0.20879
#
#
# 내수 수출
# KCC : 0.27250
# 동국제약 : 0.27651
# 롯데정밀화학 : 0.50088
# 삼천당제약 : 0.20604
# 쿠쿠홈시스 : 0.20341
# 동국제강 : 0.25479
#
#
# 내수 합계
# 셀트리온헬스케어 : 0.34684
# S-Oil : 0.33202
# SKC : 0.25093
# SK네트웍스 : 0.30298
# JYP Ent. : 0.35884
# 풍산 : 0.39529
# 동원시스템즈 : 0.25958
#
#
# 누적
# SK이노베이션 : 0.21046
#
#
# 단백질
# 알테오젠 : 0.21957
# 메드팩토 : 0.20318
# 셀리버리 : 0.29678
#
#
# 단위 사업소
# KG동부제철 : 0.22412
# 현대엘리베이 : 0.20795
# HMM : 0.23800
# 태영건설 : 0.21730
# 삼양식품 : 0.26682
#
#
# 단위 사업소 소유형태
# 현대엘리베이 : 0.23683
# HMM : 0.27105
# F&F : 0.21285
# 태영건설 : 0.24748
# 삼양식품 : 0.27855
# 남선알미늄 : 0.20539
#
#
# 당기상각
# KG동부제철 : 0.21685
# 현대엘리베이 : 0.20120
# HMM : 0.23027
# 만도 : 0.23844
# NICE평가정보 : 0.27053
# 동원산업 : 0.40682
#
#
# 당기순이익
# 오뚜기 : 0.68947
# 메리츠화재 : 0.23993
# DGB금융지주 : 0.26101
#
#
# 당기증감
# KG동부제철 : 0.21011
# HMM : 0.22311
# NICE평가정보 : 0.26211
# 동원산업 : 0.21679
#
#
# 당기증감 당기상각
# KG동부제철 : 0.23766
# HMM : 0.25237
# NICE평가정보 : 0.29649
# 동원산업 : 0.24523
#
#
# 대상지역
# 유한양행 : 0.25529
# 신풍제약 : 0.35346
# 종근당 : 0.28905
# 동아에스티 : 0.23170
# 제일약품 : 0.28257
#
#
# 대전
# 롯데하이마트 : 0.26260
#
#
# 대출
# 우리금융지주 : 0.28087
# DB손해보험 : 0.22170
# BNK금융지주 : 0.55222
# JB금융지주 : 0.27845
# DGB금융지주 : 0.22448
#
#
# 도출
#
#
# 등급
# 남선알미늄 : 0.29511
#
#
# 등기
# NAVER : 0.46576
# 삼성중공업 : 0.22055
# 대우건설 : 0.75780
# 영풍 : 0.50999
# 코오롱인더 : 0.86644
# 아난티 : 0.29583
#
#
# 디스플레이
# 삼성전자 : 0.26352
# 삼성SDI : 0.21268
# LG이노텍 : 0.28368
# 원익IPS : 0.31084
# 솔브레인홀딩스 : 0.50168
# 한솔케미칼 : 0.36262
# 동진쎄미켐 : 0.50590
# 천보 : 0.28205
# 젬백스 : 0.21905
# 톱텍 : 0.25202
# 덕산네오룩스 : 0.43646
# 에스앤에스텍 : 0.21707
#
#
# 리튬
# 에코프로비엠 : 0.83358
# 일진머티리얼즈 : 0.29905
# 후성 : 0.31784
# 에코프로 : 0.83536
# 엘앤에프 : 0.82162
#
#
# 매도
# LG디스플레이 : 0.27649
# 팬오션 : 0.69192
# 동서 : 0.82845
# 하림지주 : 0.58658
# 풍산 : 0.21355
#
#
# 매매목적
#
#
# 매출액 영업이익
# 영원무역 : 0.50340
# 화승엔터프라이즈 : 0.25194
# 영원무역홀딩스 : 0.70771
#
#
# 모듈
# 현대차 : 0.26762
# 현대모비스 : 0.31539
# 삼성전기 : 0.28428
# 삼성전기 : 0.28428
# 한국조선해양 : 0.34945
# LG이노텍 : 0.30948
# 한화솔루션 : 0.26243
# 현대위아 : 0.22719
# 삼화콘덴서 : 0.20013
# 엠씨넥스 : 0.25904
#
#
# 물류
# 삼성에스디에스 : 0.70917
# 한진칼 : 0.26775
# 현대글로비스 : 0.45080
# GS리테일 : 0.21099
# BGF리테일 : 0.48422
# 풀무원 : 0.27519
# 동아쏘시오홀딩스 : 0.41977
# 롯데정보통신 : 0.32118
#
#
# 물질
# 롯데정밀화학 : 0.22697
#
#
# 미디어
# 카카오 : 0.30401
# 스튜디오드래곤 : 0.23101
# 제일기획 : 0.20057
# 이노션 : 0.21915
# 아프리카TV : 0.45586
# 에코마케팅 : 0.67482
# 에스엠 : 0.25409
#
#
# 미만
#
#
# 바이오
# 삼성바이오로직스 : 0.25346
# 삼성물산 : 0.42170
# 에이비엘바이오 : 0.24418
# 파미셀 : 0.23762
# SK케미칼 : 0.21924
# 에이치엘비생명과학 : 0.35700
# 메디톡스 : 0.25429
# 엘앤씨바이오 : 0.44168
# 매일유업 : 0.21699
#
#
# 바이오의약품
# 삼성바이오로직스 : 0.58871
# 삼성물산 : 0.29984
# 셀트리온헬스케어 : 0.42353
# 알테오젠 : 0.39278
# 헬릭스미스 : 0.37965
# 셀리버리 : 0.25543
#
#
# 반도체
# 삼성전자 : 0.25505
# SK하이닉스 : 0.66828
# SKC : 0.31010
# 원익IPS : 0.71220
# 리노공업 : 0.59394
# 솔브레인홀딩스 : 0.54771
# 고영 : 0.65057
# 한솔케미칼 : 0.53108
# DB하이텍 : 0.65709
# 에스에프에이 : 0.74277
# 동진쎄미켐 : 0.70725
# 이오테크닉스 : 0.90234
# 티씨케이 : 0.92490
# 영풍 : 0.58161
# 천보 : 0.43812
# 젬백스 : 0.33175
# SFA반도체 : 0.98849
# 후성 : 0.52510
# 네패스 : 0.58467
# 실리콘웍스 : 0.37208
# 에스앤에스텍 : 0.74180
#
#
# 발주
# 대우조선해양 : 0.29734
# 삼성엔지니어링 : 0.21510
# 씨에스윈드 : 0.51751
#
#
# 방송
# NAVER : 0.29631
# CJ ENM : 0.51787
# 스튜디오드래곤 : 0.26730
# 태영건설 : 0.21216
# 태광산업 : 0.56979
# JYP Ent. : 0.30863
# 아프리카TV : 0.45213
# 에스엠 : 0.31501
#
#
# 배터리
# SK이노베이션 : 0.26302
# 일진머티리얼즈 : 0.28457
# 아이티엠반도체 : 0.48039
#
#
# 백화점
# 롯데지주 : 0.29039
# 한화솔루션 : 0.33750
# 롯데쇼핑 : 0.41755
# 신세계 : 0.39819
# F&F : 0.21895
# 현대백화점 : 0.79373
# 신세계인터내셔날 : 0.41931
#
#
# 병원
# 한미사이언스 : 0.21114
# 코미팜 : 0.21569
# 클래시스 : 0.30648
#
#
# 보급
# 쿠쿠홈시스 : 0.37252
#
#
# 보안
# SK텔레콤 : 0.43468
# 에스원 : 0.64788
# 현대오토에버 : 0.54387
# 롯데정보통신 : 0.33035
#
#
# 보장
# 메리츠화재 : 0.23345
# 화승엔터프라이즈 : 0.23789
#
#
# 보험
# 삼성화재 : 0.24298
# DB손해보험 : 0.37235
# 한화생명 : 0.22146
# 코리안리 : 0.22560
#
#
# 부산
# 삼성전기 : 0.22148
# 삼성전기 : 0.22148
# 롯데관광개발 : 0.39304
# 아난티 : 0.25576
# 동원산업 : 0.30029
# 롯데하이마트 : 0.44484
#
#
# 북미
# 두산밥캣 : 0.31837
# 만도 : 0.20009
#
#
# 비고 증가
# 하이트진로 : 0.29055
# 만도 : 0.25361
# 삼양식품 : 0.25170
# 동원산업 : 0.23799
#
#
# 비고 증가 감소
# 하이트진로 : 0.29055
# 만도 : 0.25361
# 삼양식품 : 0.25170
# 동원산업 : 0.23799
#
#
# 사업소 소유형태
# 현대엘리베이 : 0.22903
# HMM : 0.26212
# F&F : 0.20584
# 태영건설 : 0.23932
# NICE평가정보 : 0.30794
# 삼양식품 : 0.26938
#
#
# 사업소 소유형태 소재지
# 현대엘리베이 : 0.23362
# HMM : 0.24682
# F&F : 0.20997
# 태영건설 : 0.24413
# NICE평가정보 : 0.31412
# 삼양식품 : 0.27478
# 남선알미늄 : 0.20261
#
#
# 사업자
#
#
# 사채
# 호텔신라 : 0.28427
# 동원F&B : 0.23066
#
#
# 산업용
# 대한유화 : 0.55614
# SK가스 : 0.28439
# 동원시스템즈 : 0.28333
#
#
# 상근
# 미래에셋대우 : 0.35902
# NH투자증권 : 0.48457
# 메리츠증권 : 0.42907
# 한화 : 0.57330
#
#
# 상승시
# 화승엔터프라이즈 : 0.32373
#
#
# 상승시 하락
# 화승엔터프라이즈 : 0.34532
#
#
# 상표 자사제품
# 펄어비스 : 0.77768
#
#
# 상환
# 휴켐스 : 0.26037
#
#
# 석유화학
# LG화학 : 0.45309
# 삼성엔지니어링 : 0.24644
# 대한유화 : 0.42069
# 휴켐스 : 0.34777
#
#
# 선박
# 한국조선해양 : 0.44424
# 에이치엘비 : 0.50429
# 현대중공업지주 : 0.27928
# 삼성중공업 : 0.46365
# 현대글로비스 : 0.24027
# 대우조선해양 : 0.67110
# 팬오션 : 0.39201
# HMM : 0.20724
# 현대미포조선 : 0.69712
# KCC : 0.46326
# 동국제강 : 0.30575
# 하림지주 : 0.24282
#
#
# 선임매니저
# 미래에셋대우 : 0.24488
#
#
# 세대
# 삼성전자 : 0.27782
#
#
# 세포
# 에이비엘바이오 : 0.30590
# 차바이오텍 : 0.34474
# 셀리버리 : 0.48564
# 엘앤씨바이오 : 0.22161
# 녹십자랩셀 : 0.22093
# 네이처셀 : 0.40143
#
#
# 소유형태
# 하이트진로 : 0.27465
# 현대엘리베이 : 0.20229
# HMM : 0.23152
# 만도 : 0.23973
# 태영건설 : 0.21138
# NICE평가정보 : 0.27199
# 삼양식품 : 0.23793
# 동원산업 : 0.22496
#
#
# 소유형태 소재지
# 하이트진로 : 0.28886
# 현대엘리베이 : 0.21275
# HMM : 0.22477
# 태영건설 : 0.22232
# NICE평가정보 : 0.28606
# 삼양식품 : 0.25024
# 동원산업 : 0.23660
#
#
# 소유형태 소재지 구분
# 현대엘리베이 : 0.24187
# 태영건설 : 0.25275
# 남선알미늄 : 0.20976
#
#
# 소재지 구분
# 현대엘리베이 : 0.23053
# 태영건설 : 0.24090
#
#
# 쇼핑
# GS홈쇼핑 : 0.63951
#
#
# 수량 금액
# 오리온 : 0.23297
# 농심 : 0.43854
# 삼화콘덴서 : 0.24127
#
#
# 수석매니저
#
#
# 수수료
#
#
# 수출 내수
# 셀트리온헬스케어 : 0.28106
# S-Oil : 0.26906
# SKC : 0.20334
# SK네트웍스 : 0.24552
# 지누스 : 0.28491
# 동진쎄미켐 : 0.23188
# 클래시스 : 0.22975
# 삼천당제약 : 0.30027
# 아난티 : 0.26270
# JYP Ent. : 0.29079
# 휴켐스 : 0.54611
# 동국제강 : 0.48432
# 풍산 : 0.44845
# 동원시스템즈 : 0.23664
#
#
# 수출 내수 합계
# 셀트리온헬스케어 : 0.34953
# S-Oil : 0.33460
# SKC : 0.25287
# SK네트웍스 : 0.30533
# JYP Ent. : 0.36162
# 풍산 : 0.39835
# 동원시스템즈 : 0.26159
#
#
# 시공
# 삼성물산 : 0.24940
# 현대건설 : 0.26088
# 대우건설 : 0.25040
#
#
# 시스템 개발
# 현대엘리베이 : 0.51409
#
#
# 시점
# 씨에스윈드 : 0.65251
#
#
# 식품
# 오뚜기 : 0.40010
# 농심 : 0.64110
# 동서 : 0.35188
# 콜마비앤에이치 : 0.31626
# 삼양식품 : 0.36949
# 동원F&B : 0.69378
# 하림지주 : 0.27229
# 빙그레 : 0.33340
# 풀무원 : 0.40984
# 동원시스템즈 : 0.22336
#
#
# 신약
# 한미사이언스 : 0.32082
# 메지온 : 0.31490
# 파미셀 : 0.27194
# 코미팜 : 0.34334
# SK케미칼 : 0.20663
# 셀리버리 : 0.21377
# 엔지켐생명과학 : 0.21876
# JW중외제약 : 0.21392
# 에스티팜 : 0.35147
# 크리스탈 : 0.36619
#
#
# 신용카드
# 현대차 : 0.24600
# 삼성카드 : 0.52045
# NHN한국사이버결제 : 0.63056
#
#
# 신재
# 한국전력 : 0.33717
# 씨에스윈드 : 0.28294
#
#
# 신청
# 파미셀 : 0.25116
#
#
# 신탁
# 우리금융지주 : 0.20400
#
#
# 신한금융투자
# 신한지주 : 0.27263
#
#
# 신한금융투자 sh
# 신한지주 : 0.31892
#
#
# 신한금융투자 sh trs
# 신한지주 : 0.31865
#
#
# 실시간
# 아프리카TV : 0.24061
# 에코마케팅 : 0.26714
#
#
# 씨앗
# 신한지주 : 0.23719
#
#
# 씨앗 신한금융투자
# 신한지주 : 0.29933
#
#
# 씨앗 신한금융투자 sh
# 신한지주 : 0.29933
#
#
# 약물
# 알테오젠 : 0.26610
#
#
# 양극
# 에코프로비엠 : 0.25538
# 에코프로 : 0.24504
# 엘앤에프 : 0.35135
#
#
# 에스
# SK : 0.22133
# SK텔레콤 : 0.20267
#
#
# 엔진
# NAVER : 0.22134
# 기아차 : 0.31735
# 한국조선해양 : 0.50210
# 한진칼 : 0.21318
# 두산밥캣 : 0.22996
# 대한항공 : 0.22145
# 두산인프라코어 : 0.57451
# 두산중공업 : 0.48765
# 한화에어로스페이스 : 0.25029
# 현대위아 : 0.46245
# 두산 : 0.43673
# SK가스 : 0.23539
#
#
# 연결기업
# 코웨이 : 0.71117
# 현대글로비스 : 0.30348
# 농심 : 0.20059
# F&F : 0.36439
# KCC : 0.36714
# 삼천당제약 : 0.27759
# 영풍 : 0.23758
# 메디톡스 : 0.26713
# 아이에스동서 : 0.56256
# 동원F&B : 0.29305
# SK가스 : 0.26305
# 빙그레 : 0.70413
# 동원시스템즈 : 0.45426
#
#
# 연결조정
# 오리온 : 0.25460
# 영원무역 : 0.26784
# 만도 : 0.40088
# 한화시스템 : 0.22051
# OCI : 0.23615
# 오리온홀딩스 : 0.31610
# 동원F&B : 0.31118
#
#
# 연결회사
# LG이노텍 : 0.40908
# 두산밥캣 : 0.32854
# BGF리테일 : 0.50513
# 삼성엔지니어링 : 0.47942
# 케이엠더블유 : 0.37746
# HMM : 0.27042
# 현대백화점 : 0.30326
# 현대미포조선 : 0.41692
# OCI : 0.47863
# 한섬 : 0.23801
# 톱텍 : 0.47246
# 롯데칠성 : 0.78362
# 대한유화 : 0.25331
# 네패스 : 0.29227
# 동국제강 : 0.36571
# 에스엠 : 0.30349
# 영원무역홀딩스 : 0.22387
# 롯데정보통신 : 0.29317
#
#
# 연결회사의
# 에스원 : 0.28304
# 두산밥캣 : 0.26357
# BGF리테일 : 0.26051
# 현대백화점 : 0.21505
# OCI : 0.23697
# 톱텍 : 0.37487
# 롯데칠성 : 0.25259
# 네패스 : 0.27994
# 동국제강 : 0.21218
# 롯데정보통신 : 0.37799
#
#
# 연동
# NHN한국사이버결제 : 0.26039
# 휴켐스 : 0.51809
#
#
# 영상
# NAVER : 0.31583
# 현대모비스 : 0.21414
# 에스원 : 0.23216
# 오리온홀딩스 : 0.32793
# 아프리카TV : 0.35434
# 에코마케팅 : 0.36718
#
#
# 영업 일임투자자산운용사
# NH투자증권 : 0.41830
#
#
# 영업 일임투자자산운용사 상근
# NH투자증권 : 0.41830
#
#
# 영업의
#
#
# 오프라인
# NHN한국사이버결제 : 0.40683
# 롯데정보통신 : 0.26184
#
#
# 오픈
#
#
# 옵션
# 제일기획 : 0.49444
#
#
# 요금제
# LG : 0.21558
# KT : 0.31086
# LG유플러스 : 0.38881
#
#
# 용량
# 매일유업 : 0.60117
#
#
# 운송
# 한진칼 : 0.21447
# 현대글로비스 : 0.61178
# 팬오션 : 0.37705
# 동국제강 : 0.38427
# 하림지주 : 0.22888
#
#
# 울산
# S-Oil : 0.21357
# 현대글로비스 : 0.32957
# 현대제철 : 0.40403
# 금호석유 : 0.28163
# SK가스 : 0.24441
# 롯데하이마트 : 0.20956
# 풍산 : 0.20341
#
#
# 원료의약품
# 엔지켐생명과학 : 0.26742
# 에스티팜 : 0.62599
# 크리스탈 : 0.24774
# 종근당홀딩스 : 0.30624
#
#
# 원유
# SK이노베이션 : 0.23513
# 대우조선해양 : 0.22509
# HMM : 0.26119
# 매일유업 : 0.69696
# 빙그레 : 0.50091
#
#
# 유가증권
# 우리금융지주 : 0.29178
# DB손해보험 : 0.21057
# 한화생명 : 0.21291
#
#
# 유전자
# 씨젠 : 0.46448
# 헬릭스미스 : 0.24210
# 아미코젠 : 0.27577
#
#
# 의료기기
# 씨젠 : 0.32776
# 리노공업 : 0.73221
# 레고켐바이오 : 0.26878
# 클래시스 : 0.57593
# 엘앤씨바이오 : 0.44417
# 파마리서치프로덕트 : 0.37339
#
#
# 의약품
# 삼성바이오로직스 : 0.48037
# 셀트리온 : 0.21025
# 셀트리온헬스케어 : 0.49457
# 셀트리온제약 : 0.35119
# 알테오젠 : 0.21447
# 부광약품 : 0.54546
# 한미사이언스 : 0.33059
# 휴젤 : 0.29324
# 녹십자 : 0.27196
# 한올바이오파마 : 0.22116
# 헬릭스미스 : 0.24465
# 대웅제약 : 0.24299
# 메지온 : 0.23178
# 에이비엘바이오 : 0.20568
# 차바이오텍 : 0.29242
# 동국제약 : 0.67958
# 에이치엘비생명과학 : 0.35284
# 한국콜마 : 0.27917
# 삼천당제약 : 0.42848
# 메디톡스 : 0.59976
# 천보 : 0.23573
# 셀리버리 : 0.32040
# JW중외제약 : 0.20993
# 동아에스티 : 0.21013
# 에스티팜 : 0.29935
# 크리스탈 : 0.29199
# 안트로젠 : 0.38732
# 네이처셀 : 0.23688
# 서흥 : 0.34784
# 종근당홀딩스 : 0.50263
# CMG제약 : 0.20359
# 동아쏘시오홀딩스 : 0.23071
# 파마리서치프로덕트 : 0.21549
#
#
# 이의
#
#
# 이자
# 한화솔루션 : 0.31540
#
#
# 인공지능
# LG : 0.22547
# LG전자 : 0.33451
# 현대오토에버 : 0.31925
#
#
# 인도네시아
# 화승엔터프라이즈 : 0.39451
#
#
# 인천
# 롯데하이마트 : 0.42044
#
#
# 인터넷
# NAVER : 0.24638
# KT : 0.32825
# 이노션 : 0.23920
# 롯데관광개발 : 0.50298
# 쿠쿠홈시스 : 0.27097
# 태광산업 : 0.20902
# JYP Ent. : 0.40757
# GS홈쇼핑 : 0.33017
# 유비쿼스홀딩스 : 0.72313
#
#
# 일임투자자산운용사
# NH투자증권 : 0.39861
#
#
# 일임투자자산운용사 상근
# NH투자증권 : 0.42743
#
#
# 임대
# 현대그린푸드 : 0.30231
# 태광산업 : 0.35265
#
#
# 임상
# 셀트리온 : 0.49020
# KT&G : 0.20575
# 에이치엘비 : 0.47966
# 유한양행 : 0.68352
# 알테오젠 : 0.39375
# 한미약품 : 0.46547
# 부광약품 : 0.38718
# 제넥신 : 0.75522
# 한미사이언스 : 0.43759
# 휴젤 : 0.37673
# 녹십자 : 0.46908
# 한올바이오파마 : 0.48216
# 헬릭스미스 : 0.44448
# 대웅제약 : 0.68008
# 대웅 : 0.72640
# 신풍제약 : 0.25333
# 메지온 : 0.26529
# 에이비엘바이오 : 0.29320
# 파미셀 : 0.48001
# 종근당 : 0.59007
# 차바이오텍 : 0.49858
# 레고켐바이오 : 0.43293
# 메드팩토 : 0.35631
# 코미팜 : 0.33057
# SK케미칼 : 0.31263
# 동국제약 : 0.45587
# 에이치엘비생명과학 : 0.46329
# 영진약품 : 0.50525
# 오스코텍 : 0.53308
# 메디톡스 : 0.35802
# 젬백스 : 0.29934
# 엔지켐생명과학 : 0.26185
# JW중외제약 : 0.40048
# 동아에스티 : 0.63944
# 보령제약 : 0.23241
# 제일약품 : 0.43997
# 에스티팜 : 0.44717
# 지트리비앤티 : 0.25219
# 크리스탈 : 0.52885
# 안트로젠 : 0.25878
# 녹십자랩셀 : 0.25681
# 네이처셀 : 0.39539
# 종근당홀딩스 : 0.29806
# 동아쏘시오홀딩스 : 0.47155
# 파마리서치프로덕트 : 0.35234
#
#
# 임상 진행
#
#
# 임상시험
# 에이치엘비 : 0.31761
# 휴젤 : 0.33866
# 차바이오텍 : 0.25979
# 메드팩토 : 0.28828
# 코미팜 : 0.31839
# 에이치엘비생명과학 : 0.27784
# 젬백스 : 0.69195
# JW중외제약 : 0.40005
# 안트로젠 : 0.21645
# 녹십자랩셀 : 0.55654
# 네이처셀 : 0.37616
#
#
# 임차
# 롯데지주 : 0.40039
# 이마트 : 0.87455
# 호텔신라 : 0.74323
# 롯데쇼핑 : 0.58205
# 신세계 : 0.38337
# 한샘 : 0.37635
# 제일기획 : 0.27122
# 포스코인터내셔널 : 0.79676
# 현대백화점 : 0.41494
# 신세계인터내셔날 : 0.33095
# SK네트웍스 : 0.54358
# GS홈쇼핑 : 0.40086
# SK가스 : 0.36090
#
#
# 자가
# KT&G : 0.77301
# 롯데지주 : 0.20828
# 하이트진로 : 0.50912
# 쌍용양회 : 0.93572
# 부광약품 : 0.39794
# 롯데쇼핑 : 0.30278
# 현대엘리베이 : 0.21153
# DB하이텍 : 0.31023
# 현대로템 : 0.35941
# 코미팜 : 0.29789
# 삼양식품 : 0.47497
# 현대홈쇼핑 : 0.43533
# 한섬 : 0.80055
# 비에이치 : 0.43066
# 남선알미늄 : 0.36689
#
#
# 자금조달
#
#
# 자동화
# LS ELECTRIC : 0.39976
# 화승엔터프라이즈 : 0.33593
#
#
# 자사제품
# 펄어비스 : 0.55183
#
#
# 자산항목
# KG동부제철 : 0.22163
# 현대엘리베이 : 0.20564
# HMM : 0.23535
# 만도 : 0.24370
# 태영건설 : 0.21488
# NICE평가정보 : 0.27649
# 동원산업 : 0.22869
#
#
# 자유
#
#
# 자율스왑
# 한화솔루션 : 0.24910
# 아난티 : 0.26709
#
#
# 작용기전
# 셀트리온 : 0.20447
# 셀트리온제약 : 0.23247
# 한미약품 : 0.23592
#
#
# 잔액
# 우리금융지주 : 0.21032
#
#
# 재생
# 파마리서치프로덕트 : 0.20536
#
#
# 저감
# 현대차 : 0.31779
# 코웨이 : 0.29410
# 롯데정밀화학 : 0.23546
#
#
# 적립
# JB금융지주 : 0.41964
# 아주캐피탈 : 0.89805
#
#
# 적응증
# 셀트리온 : 0.25126
# 셀트리온제약 : 0.24020
# 유한양행 : 0.20190
# 한미약품 : 0.24248
# 휴젤 : 0.34097
# 신풍제약 : 0.20500
# 메디톡스 : 0.34868
# 동아에스티 : 0.20361
# 제일약품 : 0.22161
# 크리스탈 : 0.21415
#
#
# 전력
# LS ELECTRIC : 0.46676
# LS : 0.22253
# 대한전선 : 0.71544
# 삼화콘덴서 : 0.32859
#
#
# 전지
# LG화학 : 0.56637
# 삼성SDI : 0.86908
# 에코프로비엠 : 0.41296
# SKC : 0.24280
# 일진머티리얼즈 : 0.71520
# 아이티엠반도체 : 0.81998
# 솔브레인홀딩스 : 0.58573
# 한솔케미칼 : 0.24193
# 천보 : 0.74095
# 톱텍 : 0.39232
# 후성 : 0.75648
# NICE : 0.48858
# 에코프로 : 0.40839
# 네패스 : 0.33804
# 동화기업 : 0.73083
# 엘앤에프 : 0.39639
#
#
# 정비
# 한국항공우주 : 0.23135
# 한전KPS : 0.59621
#
#
# 제네릭
# 셀트리온 : 0.21290
# 셀트리온제약 : 0.53792
# 한국콜마 : 0.28637
# 삼천당제약 : 0.28739
# 에스티팜 : 0.28870
#
#
# 제약사
# 삼성바이오로직스 : 0.23141
#
#
# 제어
# 현대모비스 : 0.23549
# 에스원 : 0.33022
# 만도 : 0.23467
# 현대위아 : 0.44744
#
#
# 제조 방법
# SPC삼립 : 0.22479
#
#
# 제조방법
# S-Oil : 0.35829
# 하이트진로 : 0.25528
# 영진약품 : 0.20831
# 비에이치 : 0.26736
# 두산 : 0.22633
# 종근당홀딩스 : 0.20752
# 삼화콘덴서 : 0.50266
#
#
# 조성물
# KT&G : 0.31485
# 아모레퍼시픽 : 0.48719
# 셀트리온제약 : 0.20885
# 아모레G : 0.48725
# 한미사이언스 : 0.35809
# KCC : 0.27778
# 영진약품 : 0.47760
# 한국콜마 : 0.26513
# 파마리서치프로덕트 : 0.32677
#
#
# 종속기업
# JYP Ent. : 0.20397
#
#
# 종합자산운용
# 미래에셋대우 : 0.46656
#
#
# 종합자산운용 투자자산운용사
# 미래에셋대우 : 0.46333
#
#
# 주요종속회사
# 한진칼 : 0.43453
# 한솔케미칼 : 0.47815
# 영원무역 : 0.56626
# 현대그린푸드 : 0.21063
# 쿠쿠홀딩스 : 0.26771
# 영원무역홀딩스 : 0.39804
#
#
# 주택
# 삼성물산 : 0.24130
# POSCO : 0.50575
# 현대건설 : 0.22461
# GS건설 : 0.33990
# HDC현대산업개발 : 0.22797
# 아이에스동서 : 0.30105
#
#
# 증권
# 메리츠증권 : 0.48801
# 메리츠금융지주 : 0.52024
# DGB금융지주 : 0.27882
#
#
# 지배회사
# 현대제철 : 0.28690
# 쌍용양회 : 0.21987
# F&F : 0.43274
# 영원무역 : 0.26627
# 현대로템 : 0.22221
# OCI : 0.27745
# 쿠쿠홈시스 : 0.20341
# 현대그린푸드 : 0.33015
# 롯데제과 : 0.32237
# 서흥 : 0.33732
#
#
# 지점
# 메리츠증권 : 0.23453
# 제일기획 : 0.41939
#
#
# 지주회사
# 휠라홀딩스 : 0.87224
# 한미사이언스 : 0.28034
# 한국테크놀로지그룹 : 0.35969
# 오리온홀딩스 : 0.35265
# 유비쿼스홀딩스 : 0.59272
# 동아쏘시오홀딩스 : 0.27390
# 쿠쿠홀딩스 : 0.88800
# 영원무역홀딩스 : 0.42010
#
#
# 진단
# 씨젠 : 0.53723
# 롯데정보통신 : 0.22003
#
#
# 진행경과
# 한미약품 : 0.32166
# 삼천당제약 : 0.21441
#
#
# 질환
# 헬릭스미스 : 0.24664
# 지트리비앤티 : 0.30624
# 안트로젠 : 0.38700
#
#
# 차량
# 현대차 : 0.52917
# 현대모비스 : 0.43546
# 기아차 : 0.62963
# 삼성화재 : 0.20683
# 한온시스템 : 0.43236
# 현대글로비스 : 0.23347
# LG이노텍 : 0.41358
# 만도 : 0.35205
# 현대위아 : 0.48795
# 한국테크놀로지그룹 : 0.22760
# 엠씨넥스 : 0.21130
#
#
# 채권
#
#
# 추출물
# 아모레퍼시픽 : 0.32077
# 아모레G : 0.32080
#
#
# 충남
# 호텔신라 : 0.33770
# SKC : 0.22461
# KG동부제철 : 0.65724
# 롯데관광개발 : 0.22297
# 롯데하이마트 : 0.38695
#
#
# 취급
#
#
# 치료
# 셀트리온헬스케어 : 0.20968
# 한미사이언스 : 0.25584
# 휴젤 : 0.36310
# 헬릭스미스 : 0.30523
# 메드팩토 : 0.37990
# 코미팜 : 0.31860
# 클래시스 : 0.29709
# 메디톡스 : 0.20113
# 셀리버리 : 0.22316
# 엔지켐생명과학 : 0.31684
# 지트리비앤티 : 0.21210
# 안트로젠 : 0.40611
# 네이처셀 : 0.25664
# 파마리서치프로덕트 : 0.30642
#
#
# 치료제
# 에이치엘비 : 0.23693
# 부광약품 : 0.27322
# 제넥신 : 0.30563
# 헬릭스미스 : 0.31935
# 메지온 : 0.59906
# 종근당 : 0.22725
# 차바이오텍 : 0.32299
# 코미팜 : 0.23751
# SK케미칼 : 0.26674
# 오스코텍 : 0.57540
# 삼천당제약 : 0.26568
# 젬백스 : 0.20163
# 셀리버리 : 0.38201
# 엔지켐생명과학 : 0.53425
# JW중외제약 : 0.49738
# 제일약품 : 0.32599
# 지트리비앤티 : 0.67078
# 크리스탈 : 0.34347
# 안트로젠 : 0.52476
#
#
# 카드
# 우리금융지주 : 0.26751
# 삼성카드 : 0.53624
# NHN한국사이버결제 : 0.32651
# JB금융지주 : 0.39927
#
#
# 카메라
# SK하이닉스 : 0.24741
# 삼성전기 : 0.55928
# 삼성전기 : 0.55928
# 한화에어로스페이스 : 0.53422
# 엠씨넥스 : 0.74885
#
#
# 카지노
# 강원랜드 : 0.95248
# 파라다이스 : 0.90418
# 롯데관광개발 : 0.59289
# GKL : 0.96410
#
#
# 커넥터
# LS : 0.80939
# 제이앤티씨 : 0.59658
#
#
# 케어젠
# 케어젠 : 0.77710
#
#
# 콘텐츠
# NAVER : 0.28710
# 카카오 : 0.66220
# SK텔레콤 : 0.22065
# KT : 0.42748
# CJ ENM : 0.66902
# 스튜디오드래곤 : 0.88797
# 태영건설 : 0.28354
# 이노션 : 0.26325
# 오리온홀딩스 : 0.21499
# 아프리카TV : 0.58409
# 에코마케팅 : 0.45935
# 에스엠 : 0.76304
#
#
# 클라우드
# NAVER : 0.22093
# 삼성에스디에스 : 0.51064
# 더존비즈온 : 0.95624
# 한화시스템 : 0.38969
# 현대오토에버 : 0.61801
# 롯데칠성 : 0.20157
# 롯데정보통신 : 0.30165
#
#
# 타이어
# 한국타이어앤테크놀로지 : 0.94169
# 한국테크놀로지그룹 : 0.82918
# 금호타이어 : 0.93066
# 코오롱인더 : 0.20984
# 넥센타이어 : 0.93771
#
#
# 탑재
# LG전자 : 0.26081
#
#
# 태양광
# 한국전력 : 0.26893
# 한국조선해양 : 0.34992
# 한화솔루션 : 0.68499
# 에이치엘비생명과학 : 0.22541
# OCI : 0.41914
#
#
# 통신
# LS : 0.20354
# 한화시스템 : 0.21544
#
#
# 통화스왑
# POSCO : 0.38662
# SPC삼립 : 0.24682
#
#
# 투여
# 알테오젠 : 0.20074
# 메드팩토 : 0.21893
# 네이처셀 : 0.20687
#
#
# 투자자
# 현대차 : 0.34866
# 메리츠금융지주 : 0.24386
#
#
# 투자자산운용사
# 미래에셋대우 : 0.35943
# 메리츠증권 : 0.34892
# 한화 : 0.57828
#
#
# 특허 등록
# HDC현대산업개발 : 0.52199
#
#
# 특허법
# LG생활건강 : 0.23031
# 현대모비스 : 0.68904
# 현대건설 : 0.46733
# 대림산업 : 0.75483
# GS건설 : 0.82079
# 한화 : 0.20156
# 효성 : 0.60544
# HDC현대산업개발 : 0.50192
# 한화에어로스페이스 : 0.46028
# 영진약품 : 0.42805
# 현대홈쇼핑 : 0.66288
# 애경산업 : 0.40327
# 동화기업 : 0.34003
# S&T모티브 : 0.57683
# LG하우시스 : 0.64990
#
#
# 특허법 상용
# 현대건설 : 0.61464
# 효성 : 0.76197
# HDC현대산업개발 : 0.61852
# 동화기업 : 0.33559
# S&T모티브 : 0.77631
#
#
# 특허청
# 원익IPS : 0.48200
# PI첨단소재 : 0.59854
# 지트리비앤티 : 0.31962
# 엠씨넥스 : 0.56410
# 파마리서치프로덕트 : 0.41779
#
#
# 판매중단
# 하나금융지주 : 0.58223
# BNK금융지주 : 0.31586
#
#
# 패키지
# 한샘 : 0.30429
#
#
# 펀드
#
#
# 펩타이드
# 케어젠 : 0.58717
# 아미코젠 : 0.31029
#
#
# 편리
#
#
# 평균잔액
# 우리금융지주 : 0.36680
# BNK금융지주 : 0.26665
# JB금융지주 : 0.33591
# DGB금융지주 : 0.44571
# 아주캐피탈 : 0.20616
#
#
# 폐기물
# 한국조선해양 : 0.20680
# 태영건설 : 0.34044
# 롯데정밀화학 : 0.44886
# 아이에스동서 : 0.50416
#
#
# 품의 특성
# 셀트리온제약 : 0.21918
# 한미약품 : 0.22243
#
#
# 플라스틱
# 코웨이 : 0.34617
# 락앤락 : 0.72569
#
#
# 플랜트
# 현대차 : 0.23308
# 삼성물산 : 0.29984
# 현대건설 : 0.24917
# GS : 0.50814
# 삼성엔지니어링 : 0.28429
# 대우건설 : 0.28837
# 현대로템 : 0.47639
#
#
# 피부
# LG생활건강 : 0.39993
# 아모레퍼시픽 : 0.33032
# 아모레G : 0.33282
# 휴젤 : 0.24225
# 한국콜마 : 0.20720
# 엘앤씨바이오 : 0.26643
#
#
# 필름
# SKC : 0.21394
# 동서 : 0.37547
# 코오롱인더 : 0.20832
# 현대홈쇼핑 : 0.24298
# PI첨단소재 : 0.76497
# 비에이치 : 0.38301
# 네패스 : 0.20049
# 동화기업 : 0.40747
# LG하우시스 : 0.61407
# 동원시스템즈 : 0.34048
#
#
# 한국특허청
# 제이앤티씨 : 0.80040
# 아미코젠 : 0.75788
#
#
# 함유
# 아모레퍼시픽 : 0.23992
# 아모레G : 0.23995
# 애경산업 : 0.23918
#
#
# 합병
# POSCO : 0.26612
# 현대제철 : 0.32544
#
#
# 항공기
# 한진칼 : 0.63938
# 한국항공우주 : 0.93293
# 대한항공 : 0.90847
# 한화시스템 : 0.34784
#
#
# 항암제
# 에이치엘비 : 0.22048
# 메드팩토 : 0.50030
# 코미팜 : 0.23330
# 동국제약 : 0.20955
#
#
# 항체
# 셀트리온 : 0.22047
# 셀트리온헬스케어 : 0.20294
# 알테오젠 : 0.48701
# 한올바이오파마 : 0.21535
# 에이비엘바이오 : 0.59729
# 메드팩토 : 0.21635
#
#
# 향후계획
# 셀트리온 : 0.21514
# 셀트리온제약 : 0.23617
# 한미약품 : 0.23967
#
#
# 현대
# 현대중공업지주 : 0.32888
# 현대제철 : 0.32196
# 만도 : 0.30493
# 현대그린푸드 : 0.41165
#
#
# 현장
# 삼성물산 : 0.38427
# 대림산업 : 0.49440
# 대우건설 : 0.20898
#
#
# 호기
# 한국전력 : 0.67240
# GS : 0.32027
# 한전KPS : 0.53437
# 현대로템 : 0.20422
# 두산중공업 : 0.26288
# 두산 : 0.23917
#
#
# 호주
# 현대제철 : 0.21016
# 농심 : 0.25448
# 씨에스윈드 : 0.33639
#
#
# 호텔
# 강원랜드 : 0.22608
# GS : 0.21340
# 호텔신라 : 0.33535
# GS리테일 : 0.73250
# 신세계 : 0.24194
# 파라다이스 : 0.34534
# SK네트웍스 : 0.25970
# 롯데관광개발 : 0.24910
# 아난티 : 0.81046
#
#
# 홈쇼핑
# 쿠쿠홈시스 : 0.57476
# GS홈쇼핑 : 0.30814
# 락앤락 : 0.39907
# 하림지주 : 0.37736
#
#
# 화장료
# 아모레퍼시픽 : 0.50095
# 아모레G : 0.50100
# 한국콜마 : 0.34308
# 애경산업 : 0.26413
#
#
# 화장료 조성물
# 아모레퍼시픽 : 0.45419
# 아모레G : 0.45424
#
#
# 화장품
# LG생활건강 : 0.80595
# 신세계 : 0.24177
# SKC : 0.34659
# 휴젤 : 0.34460
# 신세계인터내셔날 : 0.67889
# 파미셀 : 0.21953
# 콜마비앤에이치 : 0.63731
# 클래시스 : 0.55139
# 한국콜마 : 0.69591
# 코스맥스 : 0.95078
# 엘앤씨바이오 : 0.56699
# 애경산업 : 0.74087
# 서흥 : 0.50869
#
#
# 환자
# 알테오젠 : 0.30672
# 헬릭스미스 : 0.20145
# 메지온 : 0.45923
# 차바이오텍 : 0.21223
# 코미팜 : 0.32253
# 오스코텍 : 0.25633
# 녹십자랩셀 : 0.24855
# 네이처셀 : 0.25143
#
#
# 효능
# 오스코텍 : 0.36855

# %% [markdown]
# ### 확실히 다음과 같은 경우를 보면 기업공시를 통해 해당 기업이 어떤 느낌의 회사인지 어느정도 알 수 있다.
#
# lcd
#
# LG디스플레이 : 0.36798
# 에스에프에이 : 0.32015
# 동진쎄미켐 : 0.31246
# 이오테크닉스 : 0.26577
# 에스앤에스텍 : 0.51642
#
# led
#
# LG이노텍 : 0.41868
# 케이엠더블유 : 0.71493
# 티씨케이 : 0.31262
# 서울반도체 : 0.99571
# 서울바이오시스 : 0.99080
#
# lng
#
# POSCO : 0.43179
# 삼성중공업 : 0.22774
# GS : 0.20827
# 대우조선해양 : 0.43750
# 한국가스공사 : 0.71915
# 팬오션 : 0.31830
# 포스코인터내셔널 : 0.20417
# 현대미포조선 : 0.29351
# SK가스 : 0.35074
# 하림지주 : 0.25559
#
# oled
#
# 삼성전자 : 0.25266
# 삼성SDI : 0.20197
# LG디스플레이 : 0.71606
# 에스에프에이 : 0.53070
# 이오테크닉스 : 0.21549
# 톱텍 : 0.44874
# 덕산네오룩스 : 0.87850
# 실리콘웍스 : 0.68931
# 에스앤에스텍 : 0.30062
#
#
# 건강기능식품
#
# SKC : 0.26556
# 녹십자 : 0.56956
# 헬릭스미스 : 0.30177
# 콜마비앤에이치 : 0.68442
# 빙그레 : 0.23065
# 서흥 : 0.68512
# 종근당홀딩스 : 0.24816
# 풀무원 : 0.56706
#
#
# 게임
#
# 카카오 : 0.49857
# 엔씨소프트 : 0.48727
# 넷마블 : 0.99770
# 펄어비스 : 0.28367
# NHN : 0.97598
# 더블유게임즈 : 0.95967
# 컴투스 : 0.98840
# GKL : 0.20947
# 웹젠 : 0.97137
#
#
# 대출
#
# 우리금융지주 : 0.28087
# DB손해보험 : 0.22170
# BNK금융지주 : 0.55222
# JB금융지주 : 0.27845
# DGB금융지주 : 0.22448
#
#
# 리튬
#
# 에코프로비엠 : 0.83358
# 일진머티리얼즈 : 0.29905
# 후성 : 0.31784
# 에코프로 : 0.83536
# 엘앤에프 : 0.82162

# %%
data_array[:,0]
# Out:
# array([1.59016682e-01, 1.05259535e-01, 0.00000000e+00, 0.00000000e+00,
#        3.00847090e-01, 0.00000000e+00, 0.00000000e+00, 9.00398990e-02,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.12863068e-02,
#        0.00000000e+00, 0.00000000e+00, 4.70799414e-01, 7.63236555e-02,
#        0.00000000e+00, 3.64030313e-04, 0.00000000e+00, 0.00000000e+00,
#        3.52125021e-01, 2.63740876e-02, 7.17055922e-02, 0.00000000e+00,
#        8.39675108e-02, 0.00000000e+00, 4.32614293e-02, 4.32614293e-02,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.84081917e-03,
#        2.84835836e-02, 0.00000000e+00, 0.00000000e+00, 7.46822279e-03,
#        1.09486847e-02, 2.61643303e-01, 0.00000000e+00, 6.04403152e-03,
#        2.45665438e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.40521589e-04, 0.00000000e+00, 2.24334729e-02,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.20266119e-02, 0.00000000e+00, 0.00000000e+00, 1.65858076e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.69518329e-02, 0.00000000e+00,
#        1.23851606e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 9.64725366e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.74832540e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.83740813e-03,
#        0.00000000e+00, 0.00000000e+00, 4.30541883e-02, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.46674833e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.35623842e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 4.44367219e-02, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 3.59910378e-02, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.24393542e-02, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00048056e-02, 2.03310119e-02, 0.00000000e+00, 9.85022964e-03,
#        0.00000000e+00, 9.43408840e-02, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.30712626e-02, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.81082285e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.45843098e-02, 1.38119170e-02,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.38239085e-01, 0.00000000e+00,
#        0.00000000e+00, 2.31112251e-02, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.20417434e-02, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 8.38664019e-02,
#        0.00000000e+00, 0.00000000e+00, 2.68768362e-02, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 5.44182408e-03, 0.00000000e+00, 0.00000000e+00,
#        2.52363406e-02, 5.15335019e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.30836678e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.10093690e-01, 0.00000000e+00, 2.36876360e-02,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %% [markdown]
# ## 결과 Visualization 2 (회사 -> 키워드 매치)

# %% [markdown]
# ### 다른 접근으로, 해당 회사가 어떤 키워드를 가지고 있는지도 알 수 있다.

# %%
for i, kr_name in enumerate(stock_data['korean_name']):
    
    print(kr_name)
    
    for word, score in zip(tfidf_dict, data_array[i,:]):
        if score >0.2:
            print('%s : %.5f'%(word,score))
    
    print('\n\n')
# Out:
# 삼성전자
# gb : 0.45105
# oled : 0.25266
# tv : 0.58856
# 디스플레이 : 0.26352
# 반도체 : 0.25505
# 세대 : 0.27782
#
#
#
# SK하이닉스
# gb : 0.59842
# pc : 0.21558
# 반도체 : 0.66828
# 카메라 : 0.24741
#
#
#
# 삼성바이오로직스
# 계약조건 : 0.21075
# 금액 비중 : 0.33287
# 바이오 : 0.25346
# 바이오의약품 : 0.58871
# 의약품 : 0.48037
# 제약사 : 0.23141
#
#
#
# 셀트리온
# 경쟁제품 : 0.39539
# 관련논문 : 0.21472
# 기타사항 : 0.21177
# 의약품 : 0.21025
# 임상 : 0.49020
# 작용기전 : 0.20447
# 적응증 : 0.25126
# 제네릭 : 0.21290
# 항체 : 0.22047
# 향후계획 : 0.21514
#
#
#
# NAVER
# ai : 0.30085
# 개발 진행 : 0.35314
# 등기 : 0.46576
# 방송 : 0.29631
# 엔진 : 0.22134
# 영상 : 0.31583
# 인터넷 : 0.24638
# 콘텐츠 : 0.28710
# 클라우드 : 0.22093
#
#
#
# LG화학
# lg : 0.50686
# 석유화학 : 0.45309
# 전지 : 0.56637
#
#
#
# 삼성SDI
# oled : 0.20197
# 디스플레이 : 0.21268
# 전지 : 0.86908
#
#
#
# 카카오
# 게임 : 0.49857
# 미디어 : 0.30401
# 콘텐츠 : 0.66220
#
#
#
# 현대차
# 모듈 : 0.26762
# 신용카드 : 0.24600
# 저감 : 0.31779
# 차량 : 0.52917
# 투자자 : 0.34866
# 플랜트 : 0.23308
#
#
#
# LG생활건강
# 특허법 : 0.23031
# 피부 : 0.39993
# 화장품 : 0.80595
#
#
#
# 삼성물산
# 바이오 : 0.42170
# 바이오의약품 : 0.29984
# 시공 : 0.24940
# 주택 : 0.24130
# 플랜트 : 0.29984
# 현장 : 0.38427
#
#
#
# SK
# sk : 0.85667
# 에스 : 0.22133
#
#
#
# 현대모비스
# 모듈 : 0.31539
# 영상 : 0.21414
# 제어 : 0.23549
# 차량 : 0.43546
# 특허법 : 0.68904
#
#
#
# 엔씨소프트
# us : 0.86132
# 게임 : 0.48727
#
#
#
# SK텔레콤
# ai : 0.47080
# sk : 0.30788
# 가입자 : 0.40825
# 보안 : 0.43468
# 에스 : 0.20267
# 콘텐츠 : 0.22065
#
#
#
# POSCO
# lng : 0.43179
# 주택 : 0.50575
# 통화스왑 : 0.38662
# 합병 : 0.26612
#
#
#
# 셀트리온헬스케어
# 내수 합계 : 0.34684
# 바이오의약품 : 0.42353
# 수출 내수 : 0.28106
# 수출 내수 합계 : 0.34953
# 의약품 : 0.49457
# 치료 : 0.20968
# 항체 : 0.20294
#
#
#
# 신한지주
# sh : 0.27033
# sh trs : 0.31865
# sh trs 씨앗 : 0.29933
# trs : 0.20681
# trs 씨앗 : 0.29933
# trs 씨앗 신한금융투자 : 0.29933
# 신한금융투자 : 0.27263
# 신한금융투자 sh : 0.31892
# 신한금융투자 sh trs : 0.31865
# 씨앗 : 0.23719
# 씨앗 신한금융투자 : 0.29933
# 씨앗 신한금융투자 sh : 0.29933
#
#
#
# KB금융
#
#
#
# 기아차
# 기말장부 : 0.20537
# 엔진 : 0.31735
# 차량 : 0.62963
#
#
#
# 삼성에스디에스
# ai : 0.35213
# 물류 : 0.70917
# 클라우드 : 0.51064
#
#
#
# 한국전력
# krw : 0.24051
# mw : 0.39140
# 신재 : 0.33717
# 태양광 : 0.26893
# 호기 : 0.67240
#
#
#
# LG
# gb : 0.40298
# lg : 0.70275
# lte : 0.23871
# 요금제 : 0.21558
# 인공지능 : 0.22547
#
#
#
# KT&G
# 임상 : 0.20575
# 자가 : 0.77301
# 조성물 : 0.31485
#
#
#
# LG전자
# lg : 0.83114
# tv : 0.21870
# 인공지능 : 0.33451
# 탑재 : 0.26081
#
#
#
# SK이노베이션
# sk : 0.83222
# 누적 : 0.21046
# 배터리 : 0.26302
# 원유 : 0.23513
#
#
#
# 삼성전기
# china : 0.27603
# iso : 0.31546
# pc : 0.26115
# 모듈 : 0.28428
# 부산 : 0.22148
# 카메라 : 0.55928
#
#
#
# 삼성전기
# china : 0.27603
# iso : 0.31546
# pc : 0.26115
# 모듈 : 0.28428
# 부산 : 0.22148
# 카메라 : 0.55928
#
#
#
# 아모레퍼시픽
# 조성물 : 0.48719
# 추출물 : 0.32077
# 피부 : 0.33032
# 함유 : 0.23992
# 화장료 : 0.50095
# 화장료 조성물 : 0.45419
#
#
#
# 삼성생명
#
#
#
# 삼성화재
# fy : 0.26554
# 금액 비율 : 0.21319
# 기말잔액 : 0.78116
# 보험 : 0.24298
# 차량 : 0.20683
#
#
#
# 하나금융지주
# cds : 0.51928
# 금융투자 : 0.50281
# 판매중단 : 0.58223
#
#
#
# 넷마블
# 게임 : 0.99770
#
#
#
# S-Oil
# buy : 0.62945
# 내수 합계 : 0.33202
# 수출 내수 : 0.26906
# 수출 내수 합계 : 0.33460
# 울산 : 0.21357
# 제조방법 : 0.35829
#
#
#
# 고려아연
# buy : 0.95755
#
#
#
# 우리금융지주
# 가입대상 : 0.48972
# 대출 : 0.28087
# 신탁 : 0.20400
# 유가증권 : 0.29178
# 잔액 : 0.21032
# 카드 : 0.26751
# 평균잔액 : 0.36680
#
#
#
# 한국조선해양
# 모듈 : 0.34945
# 선박 : 0.44424
# 엔진 : 0.50210
# 태양광 : 0.34992
# 폐기물 : 0.20680
#
#
#
# KT
# ai : 0.26164
# gb : 0.24502
# lte : 0.33309
# tv : 0.24529
# 가입자 : 0.24619
# 요금제 : 0.31086
# 인터넷 : 0.32825
# 콘텐츠 : 0.42748
#
#
#
# 롯데케미칼
# chemical : 0.49732
# lotte : 0.79740
#
#
#
# 기업은행
# 가입대상 : 0.95953
#
#
#
# LG유플러스
# gb : 0.72741
# lte : 0.40669
# 가입자 : 0.28178
# 요금제 : 0.38881
#
#
#
# 코웨이
# 연결기업 : 0.71117
# 저감 : 0.29410
# 플라스틱 : 0.34617
#
#
#
# 한온시스템
# service : 0.75822
# 차량 : 0.43236
#
#
#
# 오리온
# international : 0.31392
# llc : 0.25766
# ton : 0.70414
# 기타 소계 : 0.35176
# 수량 금액 : 0.23297
# 연결조정 : 0.25460
#
#
#
# 한진칼
# 물류 : 0.26775
# 엔진 : 0.21318
# 운송 : 0.21447
# 주요종속회사 : 0.43453
# 항공기 : 0.63938
#
#
#
# 강원랜드
# 카지노 : 0.95248
# 호텔 : 0.22608
#
#
#
# CJ제일제당
# china : 0.30535
# cj : 0.87615
#
#
#
# 셀트리온제약
# 경쟁제품 : 0.24206
# 관련논문 : 0.24413
# 기타사항 : 0.25830
# 의약품 : 0.35119
# 작용기전 : 0.23247
# 적응증 : 0.24020
# 제네릭 : 0.53792
# 조성물 : 0.20885
# 품의 특성 : 0.21918
# 향후계획 : 0.23617
#
#
#
# 에이치엘비
# usa : 0.23552
# 공정가치 측정 : 0.22258
# 선박 : 0.50429
# 임상 : 0.47966
# 임상시험 : 0.31761
# 치료제 : 0.23693
# 항암제 : 0.22048
#
#
#
# 미래에셋대우
# 근무 : 0.22553
# 근무 상근 : 0.42253
# 상근 : 0.35902
# 선임매니저 : 0.24488
# 종합자산운용 : 0.46656
# 종합자산운용 투자자산운용사 : 0.46333
# 투자자산운용사 : 0.35943
#
#
#
# 아모레G
# 조성물 : 0.48725
# 추출물 : 0.32080
# 피부 : 0.33282
# 함유 : 0.23995
# 화장료 : 0.50100
# 화장료 조성물 : 0.45424
#
#
#
# 현대중공업지주
# 건설기계 : 0.59066
# 선박 : 0.27928
# 현대 : 0.32888
#
#
#
# 삼성중공업
# krw : 0.36710
# lng : 0.22774
# 등기 : 0.22055
# 선박 : 0.46365
#
#
#
# LG디스플레이
# krw : 0.31260
# lcd : 0.36798
# oled : 0.71606
# tv : 0.27801
# 매도 : 0.27649
#
#
#
# 현대글로비스
# 물류 : 0.45080
# 선박 : 0.24027
# 연결기업 : 0.30348
# 운송 : 0.61178
# 울산 : 0.32957
# 차량 : 0.23347
#
#
#
# LG이노텍
# led : 0.41868
# 디스플레이 : 0.28368
# 모듈 : 0.30948
# 연결회사 : 0.40908
# 차량 : 0.41358
#
#
#
# 포스코케미칼
#
#
#
# 현대건설
# 시공 : 0.26088
# 주택 : 0.22461
# 특허법 : 0.46733
# 특허법 상용 : 0.61464
# 플랜트 : 0.24917
#
#
#
# 유한양행
# us : 0.23068
# 대상지역 : 0.25529
# 임상 : 0.68352
# 적응증 : 0.20190
#
#
#
# CJ대한통운
# cj : 0.96527
#
#
#
# 롯데지주
# lotte : 0.74198
# 백화점 : 0.29039
# 임차 : 0.40039
# 자가 : 0.20828
#
#
#
# GS
# lng : 0.20827
# mw : 0.45166
# 플랜트 : 0.50814
# 호기 : 0.32027
# 호텔 : 0.21340
#
#
#
# 더존비즈온
# 클라우드 : 0.95624
#
#
#
# 에스원
# llc : 0.20760
# vietnam : 0.26429
# 보안 : 0.64788
# 연결회사의 : 0.28304
# 영상 : 0.23216
# 제어 : 0.33022
#
#
#
# 알테오젠
# 단백질 : 0.21957
# 바이오의약품 : 0.39278
# 약물 : 0.26610
# 의약품 : 0.21447
# 임상 : 0.39375
# 투여 : 0.20074
# 항체 : 0.48701
# 환자 : 0.30672
#
#
#
# 삼성카드
# 가맹점 : 0.28495
# 구성비 : 0.48677
# 신용카드 : 0.52045
# 카드 : 0.53624
#
#
#
# DB손해보험
# 구성비 : 0.20722
# 금리 : 0.23742
# 기말잔액 : 0.70683
# 대출 : 0.22170
# 보험 : 0.37235
# 유가증권 : 0.21057
#
#
#
# 이마트
# 임차 : 0.87455
#
#
#
# 한미약품
# 경쟁제품 : 0.30383
# 관련논문 : 0.24775
# 기타사항 : 0.31662
# 임상 : 0.46547
# 작용기전 : 0.23592
# 적응증 : 0.24248
# 진행경과 : 0.32166
# 품의 특성 : 0.22243
# 향후계획 : 0.23967
#
#
#
# 현대제철
# ton : 0.29931
# 가전 : 0.31534
# 울산 : 0.40403
# 지배회사 : 0.28690
# 합병 : 0.32544
# 현대 : 0.32196
# 호주 : 0.21016
#
#
#
# 호텔신라
# 사채 : 0.28427
# 임차 : 0.74323
# 충남 : 0.33770
# 호텔 : 0.33535
#
#
#
# GS리테일
# 가맹점 : 0.43552
# 물류 : 0.21099
# 호텔 : 0.73250
#
#
#
# 대림산업
# 공구 : 0.26358
# 특허법 : 0.75483
# 현장 : 0.49440
#
#
#
# 한화솔루션
# 모듈 : 0.26243
# 백화점 : 0.33750
# 이자 : 0.31540
# 자율스왑 : 0.24910
# 태양광 : 0.68499
#
#
#
# 한국타이어앤테크놀로지
# 타이어 : 0.94169
#
#
#
# 씨젠
# 검사 : 0.53717
# 유전자 : 0.46448
# 의료기기 : 0.32776
# 진단 : 0.53723
#
#
#
# 한국금융지주
# fy : 0.95990
#
#
#
# 하이트진로
# 기초장부 : 0.25804
# 비고 증가 : 0.29055
# 비고 증가 감소 : 0.29055
# 소유형태 : 0.27465
# 소유형태 소재지 : 0.28886
# 자가 : 0.50912
# 제조방법 : 0.25528
#
#
#
# 대우조선해양
# lng : 0.43750
# 발주 : 0.29734
# 선박 : 0.67110
# 원유 : 0.22509
#
#
#
# NH투자증권
# 상근 : 0.48457
# 영업 일임투자자산운용사 : 0.41830
# 영업 일임투자자산운용사 상근 : 0.41830
# 일임투자자산운용사 : 0.39861
# 일임투자자산운용사 상근 : 0.42743
#
#
#
# 펄어비스
# 게임 : 0.28367
# 상표 자사제품 : 0.77768
# 자사제품 : 0.55183
#
#
#
# 두산밥캣
# 건설기계 : 0.78504
# 북미 : 0.31837
# 엔진 : 0.22996
# 연결회사 : 0.32854
# 연결회사의 : 0.26357
#
#
#
# 쌍용양회
# 자가 : 0.93572
# 지배회사 : 0.21987
#
#
#
# 에코프로비엠
# 리튬 : 0.83358
# 양극 : 0.25538
# 전지 : 0.41296
#
#
#
# 삼성증권
# cln : 0.94454
#
#
#
# CJ
#
#
#
# 한국가스공사
# krw : 0.56148
# lng : 0.71915
# 가스 : 0.24280
#
#
#
# 부광약품
# 의약품 : 0.54546
# 임상 : 0.38718
# 자가 : 0.39794
# 치료제 : 0.27322
#
#
#
# CJ ENM
# 기획 : 0.20678
# 방송 : 0.51787
# 콘텐츠 : 0.66902
#
#
#
# BGF리테일
# 가맹점 : 0.52355
# 물류 : 0.48422
# 연결회사 : 0.50513
# 연결회사의 : 0.26051
#
#
#
# 삼성엔지니어링
# company : 0.28407
# krw : 0.38859
# usd eur : 0.20651
# 가스 : 0.22226
# 발주 : 0.21510
# 석유화학 : 0.24644
# 연결회사 : 0.47942
# 플랜트 : 0.28429
#
#
#
# 한국항공우주
# 정비 : 0.23135
# 항공기 : 0.93293
#
#
#
# 롯데쇼핑
# lotte : 0.45784
# 백화점 : 0.41755
# 임차 : 0.58205
# 자가 : 0.30278
#
#
#
# 케이엠더블유
# led : 0.71493
# 금액 비중 : 0.49216
# 연결회사 : 0.37746
#
#
#
# 휠라홀딩스
# company : 0.38559
# 지주회사 : 0.87224
#
#
#
# 스튜디오드래곤
# 미디어 : 0.23101
# 방송 : 0.26730
# 콘텐츠 : 0.88797
#
#
#
# 신세계
# 가구 : 0.69937
# 백화점 : 0.39819
# 임차 : 0.38337
# 호텔 : 0.24194
# 화장품 : 0.24177
#
#
#
# 현대해상
# 금액 비율 : 0.74263
# 기말잔액 : 0.51830
#
#
#
# SKC
# 건강기능식품 : 0.26556
# 내수 합계 : 0.25093
# 반도체 : 0.31010
# 수출 내수 : 0.20334
# 수출 내수 합계 : 0.25287
# 전지 : 0.24280
# 충남 : 0.22461
# 필름 : 0.21394
# 화장품 : 0.34659
#
#
#
# 제넥신
# 기술이전 : 0.22822
# 임상 : 0.75522
# 치료제 : 0.30563
#
#
#
# 한미사이언스
# 병원 : 0.21114
# 신약 : 0.32082
# 의약품 : 0.33059
# 임상 : 0.43759
# 조성물 : 0.35809
# 지주회사 : 0.28034
# 치료 : 0.25584
#
#
#
# 일진머티리얼즈
# 리튬 : 0.29905
# 배터리 : 0.28457
# 전지 : 0.71520
#
#
#
# 금호석유
# iso : 0.39069
# usd eur : 0.22274
# 구성비 : 0.58855
# 울산 : 0.28163
#
#
#
# GS건설
# 주택 : 0.33990
# 특허법 : 0.82079
#
#
#
# 오뚜기
# pc : 0.37074
# ton : 0.20680
# 당기순이익 : 0.68947
# 식품 : 0.40010
#
#
#
# 메리츠증권
# cln : 0.25026
# 근무 : 0.25926
# 근무 상근 : 0.48001
# 상근 : 0.42907
# 증권 : 0.48801
# 지점 : 0.23453
# 투자자산운용사 : 0.34892
#
#
#
# 농심
# ton : 0.24852
# 금액 수량 : 0.29084
# 금액 수량 금액 : 0.29390
# 수량 금액 : 0.43854
# 식품 : 0.64110
# 연결기업 : 0.20059
# 호주 : 0.25448
#
#
#
# 한샘
# 가구 : 0.71842
# 공간 : 0.26636
# 구성비 : 0.23881
# 임차 : 0.37635
# 패키지 : 0.30429
#
#
#
# 제일기획
# limited : 0.52767
# llc : 0.21509
# tv : 0.24679
# 미디어 : 0.20057
# 옵션 : 0.49444
# 임차 : 0.27122
# 지점 : 0.41939
#
#
#
# 팬오션
# lng : 0.31830
# 매도 : 0.69192
# 선박 : 0.39201
# 운송 : 0.37705
#
#
#
# 키움증권
#
#
#
# 대한항공
# 엔진 : 0.22145
# 항공기 : 0.90847
#
#
#
# 한화
# 상근 : 0.57330
# 투자자산운용사 : 0.57828
# 특허법 : 0.20156
#
#
#
# 휴젤
# fda : 0.20989
# 의약품 : 0.29324
# 임상 : 0.37673
# 임상시험 : 0.33866
# 적응증 : 0.34097
# 치료 : 0.36310
# 피부 : 0.24225
# 화장품 : 0.34460
#
#
#
# 녹십자
# 건강기능식품 : 0.56956
# 의약품 : 0.27196
# 임상 : 0.46908
#
#
#
# 포스코인터내셔널
# international : 0.49118
# lng : 0.20417
# 임차 : 0.79676
#
#
#
# SK머티리얼즈
#
#
#
# 한올바이오파마
# for : 0.56827
# 의약품 : 0.22116
# 임상 : 0.48216
# 항체 : 0.21535
#
#
#
# 헬릭스미스
# 건강기능식품 : 0.30177
# 바이오의약품 : 0.37965
# 유전자 : 0.24210
# 의약품 : 0.24465
# 임상 : 0.44448
# 질환 : 0.24664
# 치료 : 0.30523
# 치료제 : 0.31935
# 환자 : 0.20145
#
#
#
# 대웅제약
# 의약품 : 0.24299
# 임상 : 0.68008
#
#
#
# NHN
# 게임 : 0.97598
#
#
#
# BNK금융지주
# 가입대상 : 0.52703
# 대출 : 0.55222
# 판매중단 : 0.31586
# 평균잔액 : 0.26665
#
#
#
# 대웅
# 임상 : 0.72640
#
#
#
# KG동부제철
# 단위 사업소 : 0.22412
# 당기상각 : 0.21685
# 당기증감 : 0.21011
# 당기증감 당기상각 : 0.23766
# 자산항목 : 0.22163
# 충남 : 0.65724
#
#
#
# 현대엘리베이
# 단위 사업소 : 0.20795
# 단위 사업소 소유형태 : 0.23683
# 당기상각 : 0.20120
# 사업소 소유형태 : 0.22903
# 사업소 소유형태 소재지 : 0.23362
# 소유형태 : 0.20229
# 소유형태 소재지 : 0.21275
# 소유형태 소재지 구분 : 0.24187
# 소재지 구분 : 0.23053
# 시스템 개발 : 0.51409
# 자가 : 0.21153
# 자산항목 : 0.20564
#
#
#
# 동서
# 매도 : 0.82845
# 식품 : 0.35188
# 필름 : 0.37547
#
#
#
# HMM
# 기말장부 : 0.25877
# 기초장부 : 0.21752
# 단위 사업소 : 0.23800
# 단위 사업소 소유형태 : 0.27105
# 당기상각 : 0.23027
# 당기증감 : 0.22311
# 당기증감 당기상각 : 0.25237
# 사업소 소유형태 : 0.26212
# 사업소 소유형태 소재지 : 0.24682
# 선박 : 0.20724
# 소유형태 : 0.23152
# 소유형태 소재지 : 0.22477
# 연결회사 : 0.27042
# 원유 : 0.26119
# 자산항목 : 0.23535
#
#
#
# 메리츠화재
# 금액 비율 : 0.56137
# 기말잔액 : 0.68564
# 당기순이익 : 0.23993
# 보장 : 0.23345
#
#
#
# 원익IPS
# 디스플레이 : 0.31084
# 반도체 : 0.71220
# 특허청 : 0.48200
#
#
#
# 리노공업
# 검사 : 0.20984
# 반도체 : 0.59394
# 의료기기 : 0.73221
#
#
#
# 신풍제약
# us : 0.59157
# 계약조건 : 0.29885
# 기타사항 : 0.33067
# 대상지역 : 0.35346
# 임상 : 0.25333
# 적응증 : 0.20500
#
#
#
# 메지온
# 신약 : 0.31490
# 의약품 : 0.23178
# 임상 : 0.26529
# 치료제 : 0.59906
# 환자 : 0.45923
#
#
#
# F&F
# 기초장부 당기증감 : 0.20997
# 기초장부 당기증감 당기상각 : 0.22055
# 단위 사업소 소유형태 : 0.21285
# 백화점 : 0.21895
# 사업소 소유형태 : 0.20584
# 사업소 소유형태 소재지 : 0.20997
# 연결기업 : 0.36439
# 지배회사 : 0.43274
#
#
#
# 아이티엠반도체
# 배터리 : 0.48039
# 전지 : 0.81998
#
#
#
# 대우건설
# 등기 : 0.75780
# 시공 : 0.25040
# 플랜트 : 0.28837
# 현장 : 0.20898
#
#
#
# 현대백화점
# 백화점 : 0.79373
# 연결회사 : 0.30326
# 연결회사의 : 0.21505
# 임차 : 0.41494
#
#
#
# 솔브레인홀딩스
# 디스플레이 : 0.50168
# 반도체 : 0.54771
# 전지 : 0.58573
#
#
#
# 효성
# 특허법 : 0.60544
# 특허법 상용 : 0.76197
#
#
#
# 메리츠금융지주
# cln : 0.67642
# 금액 비율 : 0.20829
# 증권 : 0.52024
# 투자자 : 0.24386
#
#
#
# 한전KPS
# mw : 0.39767
# 검사 : 0.29962
# 정비 : 0.59621
# 호기 : 0.53437
#
#
#
# 현대미포조선
# lng : 0.29351
# vietnam : 0.20077
# 선박 : 0.69712
# 연결회사 : 0.41692
#
#
#
# 더블유게임즈
# 게임 : 0.95967
#
#
#
# 고영
# 검사 : 0.68953
# 반도체 : 0.65057
#
#
#
# 에이비엘바이오
# 기술이전 : 0.26779
# 바이오 : 0.24418
# 세포 : 0.30590
# 의약품 : 0.20568
# 임상 : 0.29320
# 항체 : 0.59729
#
#
#
# 컴투스
# 게임 : 0.98840
#
#
#
# 신세계인터내셔날
# 구성비 : 0.39001
# 백화점 : 0.41931
# 임차 : 0.33095
# 화장품 : 0.67889
#
#
#
# HDC현대산업개발
# 주택 : 0.22797
# 특허 등록 : 0.52199
# 특허법 : 0.50192
# 특허법 상용 : 0.61852
#
#
#
# 한솔케미칼
# ton : 0.20850
# 디스플레이 : 0.36262
# 반도체 : 0.53108
# 전지 : 0.24193
# 주요종속회사 : 0.47815
#
#
#
# 파미셀
# cell : 0.37754
# 바이오 : 0.23762
# 신약 : 0.27194
# 신청 : 0.25116
# 임상 : 0.48001
# 화장품 : 0.21953
#
#
#
# LS ELECTRIC
# buy : 0.50548
# 자동화 : 0.39976
# 전력 : 0.46676
#
#
#
# 파라다이스
# 카지노 : 0.90418
# 호텔 : 0.34534
#
#
#
# 일양약품
#
#
#
# 영원무역
# 검사 : 0.27270
# 매출액 영업이익 : 0.50340
# 연결조정 : 0.26784
# 주요종속회사 : 0.56626
# 지배회사 : 0.26627
#
#
#
# 한화생명
# 금액 비율 : 0.55700
# 기말잔액 : 0.69161
# 보험 : 0.22146
# 유가증권 : 0.21291
#
#
#
# 두산솔루스
#
#
#
# 두산인프라코어
# 건설기계 : 0.77361
# 엔진 : 0.57451
#
#
#
# DB하이텍
# 반도체 : 0.65709
# 자가 : 0.31023
#
#
#
# 현대로템
# 가스 : 0.37490
# 자가 : 0.35941
# 지배회사 : 0.22221
# 플랜트 : 0.47639
# 호기 : 0.20422
#
#
#
# 콜마비앤에이치
# 건강기능식품 : 0.68442
# 식품 : 0.31626
# 화장품 : 0.63731
#
#
#
# 종근당
# 계약조건 : 0.24151
# 계약체결일 : 0.20382
# 기타사항 : 0.35562
# 대상지역 : 0.28905
# 임상 : 0.59007
# 치료제 : 0.22725
#
#
#
# SK네트웍스
# sk : 0.47980
# 내수 합계 : 0.30298
# 수출 내수 : 0.24552
# 수출 내수 합계 : 0.30533
# 임차 : 0.54358
# 호텔 : 0.25970
#
#
#
# 에스에프에이
# lcd : 0.32015
# oled : 0.53070
# 반도체 : 0.74277
#
#
#
# 두산중공업
# mw : 0.27262
# 건설기계 : 0.68671
# 엔진 : 0.48765
# 호기 : 0.26288
#
#
#
# KCC
# kr : 0.34890
# 건축 : 0.33167
# 내수 수출 : 0.27250
# 선박 : 0.46326
# 연결기업 : 0.36714
# 조성물 : 0.27778
#
#
#
# 차바이오텍
# cell : 0.28286
# 세포 : 0.34474
# 의약품 : 0.29242
# 임상 : 0.49858
# 임상시험 : 0.25979
# 치료제 : 0.32299
# 환자 : 0.21223
#
#
#
# 한화에어로스페이스
# company : 0.25013
# us : 0.21764
# 엔진 : 0.25029
# 카메라 : 0.53422
# 특허법 : 0.46028
#
#
#
# LS
# lte : 0.22257
# 전력 : 0.22253
# 커넥터 : 0.80939
# 통신 : 0.20354
#
#
#
# 레고켐바이오
# 기술이전 : 0.78519
# 의료기기 : 0.26878
# 임상 : 0.43293
#
#
#
# 만도
# 기술이전 : 0.31212
# 당기상각 : 0.23844
# 북미 : 0.20009
# 비고 증가 : 0.25361
# 비고 증가 감소 : 0.25361
# 소유형태 : 0.23973
# 연결조정 : 0.40088
# 자산항목 : 0.24370
# 제어 : 0.23467
# 차량 : 0.35205
# 현대 : 0.30493
#
#
#
# 태영건설
# 단위 사업소 : 0.21730
# 단위 사업소 소유형태 : 0.24748
# 방송 : 0.21216
# 사업소 소유형태 : 0.23932
# 사업소 소유형태 소재지 : 0.24413
# 소유형태 : 0.21138
# 소유형태 소재지 : 0.22232
# 소유형태 소재지 구분 : 0.25275
# 소재지 구분 : 0.24090
# 자산항목 : 0.21488
# 콘텐츠 : 0.28354
# 폐기물 : 0.34044
#
#
#
# NHN한국사이버결제
# 가맹점 : 0.37179
# 신용카드 : 0.63056
# 연동 : 0.26039
# 오프라인 : 0.40683
# 카드 : 0.32651
#
#
#
# 메드팩토
# 단백질 : 0.20318
# 임상 : 0.35631
# 임상시험 : 0.28828
# 치료 : 0.37990
# 투여 : 0.21893
# 항암제 : 0.50030
# 항체 : 0.21635
#
#
#
# 코미팜
# 병원 : 0.21569
# 신약 : 0.34334
# 임상 : 0.33057
# 임상시험 : 0.31839
# 자가 : 0.29789
# 치료 : 0.31860
# 치료제 : 0.23751
# 항암제 : 0.23330
# 환자 : 0.32253
#
#
#
# 녹십자홀딩스
#
#
#
# 지누스
# 가구 : 0.88804
# 수출 내수 : 0.28491
#
#
#
# SK케미칼
# buy : 0.24531
# sk : 0.52159
# 기타사항 : 0.21190
# 바이오 : 0.21924
# 신약 : 0.20663
# 임상 : 0.31263
# 치료제 : 0.26674
#
#
#
# NICE평가정보
# 기초장부 : 0.25554
# 기초장부 당기증감 : 0.31412
# 기초장부 당기증감 당기상각 : 0.32996
# 당기상각 : 0.27053
# 당기증감 : 0.26211
# 당기증감 당기상각 : 0.29649
# 사업소 소유형태 : 0.30794
# 사업소 소유형태 소재지 : 0.31412
# 소유형태 : 0.27199
# 소유형태 소재지 : 0.28606
# 자산항목 : 0.27649
#
#
#
# 동진쎄미켐
# lcd : 0.31246
# 디스플레이 : 0.50590
# 반도체 : 0.70725
# 수출 내수 : 0.23188
#
#
#
# 동국제약
# 내수 수출 : 0.27651
# 의약품 : 0.67958
# 임상 : 0.45587
# 항암제 : 0.20955
#
#
#
# 에이치엘비생명과학
# 공간 : 0.27051
# 바이오 : 0.35700
# 의약품 : 0.35284
# 임상 : 0.46329
# 임상시험 : 0.27784
# 태양광 : 0.22541
#
#
#
# 클래시스
# 병원 : 0.30648
# 수출 내수 : 0.22975
# 의료기기 : 0.57593
# 치료 : 0.29709
# 화장품 : 0.55139
#
#
#
# 영진약품
# 임상 : 0.50525
# 제조방법 : 0.20831
# 조성물 : 0.47760
# 특허법 : 0.42805
#
#
#
# 이오테크닉스
# lcd : 0.26577
# oled : 0.21549
# 반도체 : 0.90234
#
#
#
# 현대위아
# krw : 0.45438
# 모듈 : 0.22719
# 엔진 : 0.46245
# 제어 : 0.44744
# 차량 : 0.48795
#
#
#
# 한국콜마
# 의약품 : 0.27917
# 제네릭 : 0.28637
# 조성물 : 0.26513
# 피부 : 0.20720
# 화장료 : 0.34308
# 화장품 : 0.69591
#
#
#
# 티씨케이
# led : 0.31262
# 반도체 : 0.92490
#
#
#
# 이노션
# llc : 0.36558
# 공간 : 0.30364
# 금액 비중 : 0.24503
# 기획 : 0.56956
# 미디어 : 0.21915
# 인터넷 : 0.23920
# 콘텐츠 : 0.26325
#
#
#
# 한화시스템
# ai : 0.58108
# 연결조정 : 0.22051
# 클라우드 : 0.38969
# 통신 : 0.21544
# 항공기 : 0.34784
#
#
#
# JB금융지주
# 가맹점 : 0.21443
# 가입대상 : 0.42398
# 대출 : 0.27845
# 적립 : 0.41964
# 카드 : 0.39927
# 평균잔액 : 0.33591
#
#
#
# 한국테크놀로지그룹
# 지주회사 : 0.35969
# 차량 : 0.22760
# 타이어 : 0.82918
#
#
#
# 삼양식품
# 기초장부 : 0.22354
# 단위 사업소 : 0.26682
# 단위 사업소 소유형태 : 0.27855
# 비고 증가 : 0.25170
# 비고 증가 감소 : 0.25170
# 사업소 소유형태 : 0.26938
# 사업소 소유형태 소재지 : 0.27478
# 소유형태 : 0.23793
# 소유형태 소재지 : 0.25024
# 식품 : 0.36949
# 자가 : 0.47497
#
#
#
# 롯데관광개발
# 부산 : 0.39304
# 인터넷 : 0.50298
# 충남 : 0.22297
# 카지노 : 0.59289
# 호텔 : 0.24910
#
#
#
# 금호타이어
# 타이어 : 0.93066
#
#
#
# 코리안리
# 기말잔액 : 0.93940
# 보험 : 0.22560
#
#
#
# 아시아나항공
#
#
#
# 롯데정밀화학
# 건축 : 0.32659
# 계약조건 : 0.38948
# 내수 수출 : 0.50088
# 물질 : 0.22697
# 저감 : 0.23546
# 폐기물 : 0.44886
#
#
#
# 오스코텍
# 임상 : 0.53308
# 치료제 : 0.57540
# 환자 : 0.25633
# 효능 : 0.36855
#
#
#
# OCI
# iso : 0.31643
# 연결조정 : 0.23615
# 연결회사 : 0.47863
# 연결회사의 : 0.23697
# 지배회사 : 0.27745
# 태양광 : 0.41914
#
#
#
# 삼천당제약
# 기타사항 : 0.21106
# 내수 수출 : 0.20604
# 수출 내수 : 0.30027
# 연결기업 : 0.27759
# 의약품 : 0.42848
# 제네릭 : 0.28739
# 진행경과 : 0.21441
# 치료제 : 0.26568
#
#
#
# 영풍
# vietnam : 0.21452
# 등기 : 0.50999
# 반도체 : 0.58161
# 연결기업 : 0.23758
#
#
#
# 메디톡스
# 바이오 : 0.25429
# 연결기업 : 0.26713
# 의약품 : 0.59976
# 임상 : 0.35802
# 적응증 : 0.34868
# 치료 : 0.20113
#
#
#
# 아이에스동서
# krw : 0.26249
# ton : 0.39129
# 연결기업 : 0.56256
# 주택 : 0.30105
# 폐기물 : 0.50416
#
#
#
# 천보
# 디스플레이 : 0.28205
# 반도체 : 0.43812
# 의약품 : 0.23573
# 전지 : 0.74095
#
#
#
# 코스맥스
# 화장품 : 0.95078
#
#
#
# 코오롱인더
# 등기 : 0.86644
# 타이어 : 0.20984
# 필름 : 0.20832
#
#
#
# DGB금융지주
# 구성비 : 0.20982
# 금액 비율 : 0.45801
# 당기순이익 : 0.26101
# 대출 : 0.22448
# 증권 : 0.27882
# 평균잔액 : 0.44571
#
#
#
# GKL
# 게임 : 0.20947
# 카지노 : 0.96410
#
#
#
# 젬백스
# 디스플레이 : 0.21905
# 반도체 : 0.33175
# 임상 : 0.29934
# 임상시험 : 0.69195
# 치료제 : 0.20163
#
#
#
# 케어젠
# 케어젠 : 0.77710
# 펩타이드 : 0.58717
#
#
#
# 대상
#
#
#
# 현대홈쇼핑
# 자가 : 0.43533
# 특허법 : 0.66288
# 필름 : 0.24298
#
#
#
# 쿠쿠홈시스
# 가전 : 0.22357
# 내수 수출 : 0.20341
# 보급 : 0.37252
# 인터넷 : 0.27097
# 지배회사 : 0.20341
# 홈쇼핑 : 0.57476
#
#
#
# 오리온홀딩스
# ton : 0.40980
# 기타 소계 : 0.21836
# 기획 : 0.49838
# 연결조정 : 0.31610
# 영상 : 0.32793
# 지주회사 : 0.35265
# 콘텐츠 : 0.21499
#
#
#
# 셀리버리
# 기술이전 : 0.23092
# 단백질 : 0.29678
# 바이오의약품 : 0.25543
# 세포 : 0.48564
# 신약 : 0.21377
# 의약품 : 0.32040
# 치료 : 0.22316
# 치료제 : 0.38201
#
#
#
# 현대오토에버
# ai : 0.23824
# 보안 : 0.54387
# 인공지능 : 0.31925
# 클라우드 : 0.61801
#
#
#
# 한섬
# 연결회사 : 0.23801
# 자가 : 0.80055
#
#
#
# 다우기술
#
#
#
# SFA반도체
# 반도체 : 0.98849
#
#
#
# 현대그린푸드
# 가구 : 0.47955
# 건설기계 : 0.47557
# 임대 : 0.30231
# 주요종속회사 : 0.21063
# 지배회사 : 0.33015
# 현대 : 0.41165
#
#
#
# 톱텍
# oled : 0.44874
# 디스플레이 : 0.25202
# 연결회사 : 0.47246
# 연결회사의 : 0.37487
# 전지 : 0.39232
#
#
#
# 엔지켐생명과학
# kr : 0.41796
# 신약 : 0.21876
# 원료의약품 : 0.26742
# 임상 : 0.26185
# 치료 : 0.31684
# 치료제 : 0.53425
#
#
#
# 태광산업
# ton : 0.31250
# 가입자 : 0.51305
# 방송 : 0.56979
# 인터넷 : 0.20902
# 임대 : 0.35265
#
#
#
# PI첨단소재
# 특허청 : 0.59854
# 필름 : 0.76497
#
#
#
# 아난티
# 등기 : 0.29583
# 부산 : 0.25576
# 수출 내수 : 0.26270
# 자율스왑 : 0.26709
# 호텔 : 0.81046
#
#
#
# 서울반도체
# led : 0.99571
#
#
#
# JW중외제약
# us : 0.21827
# 신약 : 0.21392
# 의약품 : 0.20993
# 임상 : 0.40048
# 임상시험 : 0.40005
# 치료제 : 0.49738
#
#
#
# 롯데칠성
# 공정가치 측정 : 0.34174
# 연결회사 : 0.78362
# 연결회사의 : 0.25259
# 클라우드 : 0.20157
#
#
#
# RFHIC
# gan : 0.97438
#
#
#
# 엘앤씨바이오
# 바이오 : 0.44168
# 세포 : 0.22161
# 의료기기 : 0.44417
# 피부 : 0.26643
# 화장품 : 0.56699
#
#
#
# 화승엔터프라이즈
# 근무 : 0.21509
# 매출액 영업이익 : 0.25194
# 보장 : 0.23789
# 상승시 : 0.32373
# 상승시 하락 : 0.34532
# 인도네시아 : 0.39451
# 자동화 : 0.33593
#
#
#
# 동아에스티
# 기타사항 : 0.35031
# 대상지역 : 0.23170
# 의약품 : 0.21013
# 임상 : 0.63944
# 적응증 : 0.20361
#
#
#
# 동원산업
# 기초장부 : 0.21135
# 기초장부 당기증감 : 0.25981
# 기초장부 당기증감 당기상각 : 0.27291
# 당기상각 : 0.40682
# 당기증감 : 0.21679
# 당기증감 당기상각 : 0.24523
# 부산 : 0.30029
# 비고 증가 : 0.23799
# 비고 증가 감소 : 0.23799
# 소유형태 : 0.22496
# 소유형태 소재지 : 0.23660
# 자산항목 : 0.22869
#
#
#
# 롯데제과
# lotte : 0.87622
# 지배회사 : 0.32237
#
#
#
# JYP Ent.
# limited : 0.24915
# 내수 합계 : 0.35884
# 방송 : 0.30863
# 수출 내수 : 0.29079
# 수출 내수 합계 : 0.36162
# 인터넷 : 0.40757
# 종속기업 : 0.20397
#
#
#
# 보령제약
# mg : 0.91004
# 임상 : 0.23241
#
#
#
# 동원F&B
# cny : 0.21697
# iso : 0.22933
# usd eur : 0.20919
# 사채 : 0.23066
# 식품 : 0.69378
# 연결기업 : 0.29305
# 연결조정 : 0.31118
#
#
#
# 제일약품
# 계약조건 : 0.23364
# 계약체결일 : 0.20163
# 기타사항 : 0.43457
# 대상지역 : 0.28257
# 임상 : 0.43997
# 적응증 : 0.22161
# 치료제 : 0.32599
#
#
#
# 웹젠
# 게임 : 0.97137
#
#
#
# GS홈쇼핑
# 쇼핑 : 0.63951
# 인터넷 : 0.33017
# 임차 : 0.40086
# 홈쇼핑 : 0.30814
#
#
#
# 국일제지
#
#
#
# 후성
# 리튬 : 0.31784
# 반도체 : 0.52510
# 전지 : 0.75648
#
#
#
# 에스티팜
# 신약 : 0.35147
# 원료의약품 : 0.62599
# 의약품 : 0.29935
# 임상 : 0.44717
# 제네릭 : 0.28870
#
#
#
# NICE
# cd : 0.32480
# 가맹점 : 0.67550
# 전지 : 0.48858
#
#
#
# 대한유화
# 가스 : 0.59282
# 산업용 : 0.55614
# 석유화학 : 0.42069
# 연결회사 : 0.25331
#
#
#
# 지트리비앤티
# 임상 : 0.25219
# 질환 : 0.30624
# 치료 : 0.21210
# 치료제 : 0.67078
# 특허청 : 0.31962
#
#
#
# 제이앤티씨
# 커넥터 : 0.59658
# 한국특허청 : 0.80040
#
#
#
# 덕산네오룩스
# oled : 0.87850
# 디스플레이 : 0.43646
#
#
#
# 휴켐스
# 상환 : 0.26037
# 석유화학 : 0.34777
# 수출 내수 : 0.54611
# 연동 : 0.51809
#
#
#
# LIG넥스원
#
#
#
# 에코프로
# 리튬 : 0.83536
# 양극 : 0.24504
# 전지 : 0.40839
#
#
#
# 포스코 ICT
#
#
#
# 비에이치
# 자가 : 0.43066
# 제조방법 : 0.26736
# 필름 : 0.38301
#
#
#
# 아주캐피탈
# 적립 : 0.89805
# 평균잔액 : 0.20616
#
#
#
# 두산
# cell : 0.26283
# mw : 0.20293
# 건설기계 : 0.61185
# 엔진 : 0.43673
# 제조방법 : 0.22633
# 호기 : 0.23917
#
#
#
# 유비쿼스홀딩스
# 인터넷 : 0.72313
# 지주회사 : 0.59272
#
#
#
# SK가스
# buy : 0.33678
# lng : 0.35074
# sk : 0.41026
# 산업용 : 0.28439
# 엔진 : 0.23539
# 연결기업 : 0.26305
# 울산 : 0.24441
# 임차 : 0.36090
#
#
#
# 네패스
# chemical : 0.33532
# 개발 진행 : 0.23081
# 반도체 : 0.58467
# 연결회사 : 0.29227
# 연결회사의 : 0.27994
# 전지 : 0.33804
# 필름 : 0.20049
#
#
#
# 크리스탈
# 신약 : 0.36619
# 원료의약품 : 0.24774
# 의약품 : 0.29199
# 임상 : 0.52885
# 적응증 : 0.21415
# 치료제 : 0.34347
#
#
#
# 롯데하이마트
# tv : 0.27566
# 가전 : 0.35227
# 대전 : 0.26260
# 부산 : 0.44484
# 울산 : 0.20956
# 인천 : 0.42044
# 충남 : 0.38695
#
#
#
# 씨에스윈드
# 발주 : 0.51751
# 시점 : 0.65251
# 신재 : 0.28294
# 호주 : 0.33639
#
#
#
# 아프리카TV
# 미디어 : 0.45586
# 방송 : 0.45213
# 실시간 : 0.24061
# 영상 : 0.35434
# 콘텐츠 : 0.58409
#
#
#
# 남선알미늄
# 기초장부 당기증감 : 0.20261
# 기초장부 당기증감 당기상각 : 0.21282
# 단위 사업소 소유형태 : 0.20539
# 등급 : 0.29511
# 사업소 소유형태 소재지 : 0.20261
# 소유형태 소재지 구분 : 0.20976
# 자가 : 0.36689
#
#
#
# 동국제강
# 가전 : 0.36406
# 내수 수출 : 0.25479
# 선박 : 0.30575
# 수출 내수 : 0.48432
# 연결회사 : 0.36571
# 연결회사의 : 0.21218
# 운송 : 0.38427
#
#
#
# 락앤락
# usd eur : 0.22740
# 가구 : 0.34706
# 플라스틱 : 0.72569
# 홈쇼핑 : 0.39907
#
#
#
# 매일유업
# 바이오 : 0.21699
# 용량 : 0.60117
# 원유 : 0.69696
#
#
#
# 애경산업
# 특허법 : 0.40327
# 함유 : 0.23918
# 화장료 : 0.26413
# 화장품 : 0.74087
#
#
#
# 안트로젠
# 의약품 : 0.38732
# 임상 : 0.25878
# 임상시험 : 0.21645
# 질환 : 0.38700
# 치료 : 0.40611
# 치료제 : 0.52476
#
#
#
# 서울바이오시스
# led : 0.99080
#
#
#
# 하림지주
# lng : 0.25559
# 매도 : 0.58658
# 선박 : 0.24282
# 식품 : 0.27229
# 운송 : 0.22888
# 홈쇼핑 : 0.37736
#
#
#
# 빙그레
# 건강기능식품 : 0.23065
# 식품 : 0.33340
# 연결기업 : 0.70413
# 원유 : 0.50091
#
#
#
# 녹십자랩셀
# kr : 0.21757
# mg : 0.46558
# 세포 : 0.22093
# 임상 : 0.25681
# 임상시험 : 0.55654
# 환자 : 0.24855
#
#
#
# 실리콘웍스
# china : 0.20761
# oled : 0.68931
# tv : 0.46834
# 반도체 : 0.37208
#
#
#
# KG이니시스
#
#
#
# 네이처셀
# fda : 0.26180
# 세포 : 0.40143
# 의약품 : 0.23688
# 임상 : 0.39539
# 임상시험 : 0.37616
# 치료 : 0.25664
# 투여 : 0.20687
# 환자 : 0.25143
#
#
#
# 동화기업
# 전지 : 0.73083
# 특허법 : 0.34003
# 특허법 상용 : 0.33559
# 필름 : 0.40747
#
#
#
# 대한전선
# al : 0.23270
# ton : 0.47632
# 전력 : 0.71544
#
#
#
# 아미코젠
# 유전자 : 0.27577
# 펩타이드 : 0.31029
# 한국특허청 : 0.75788
#
#
#
# 서흥
# 건강기능식품 : 0.68512
# 의약품 : 0.34784
# 지배회사 : 0.33732
# 화장품 : 0.50869
#
#
#
# 종근당홀딩스
# 건강기능식품 : 0.24816
# 계약조건 : 0.26462
# 원료의약품 : 0.30624
# 의약품 : 0.50263
# 임상 : 0.29806
# 제조방법 : 0.20752
#
#
#
# 한전기술
#
#
#
# 풀무원
# usa : 0.23860
# 가맹점 : 0.41107
# 건강기능식품 : 0.56706
# 물류 : 0.27519
# 식품 : 0.40984
#
#
#
# S&T모티브
# 특허법 : 0.57683
# 특허법 상용 : 0.77631
#
#
#
# 에스앤에스텍
# lcd : 0.51642
# oled : 0.30062
# 디스플레이 : 0.21707
# 반도체 : 0.74180
#
#
#
# CMG제약
# mg : 0.92201
# 의약품 : 0.20359
#
#
#
# 동아쏘시오홀딩스
# 물류 : 0.41977
# 의약품 : 0.23071
# 임상 : 0.47155
# 지주회사 : 0.27390
#
#
#
# 에코마케팅
# 기획 : 0.20879
# 미디어 : 0.67482
# 실시간 : 0.26714
# 영상 : 0.36718
# 콘텐츠 : 0.45935
#
#
#
# SPC삼립
# ton : 0.81996
# 제조 방법 : 0.22479
# 통화스왑 : 0.24682
#
#
#
# 풍산
# 내수 합계 : 0.39529
# 매도 : 0.21355
# 수출 내수 : 0.44845
# 수출 내수 합계 : 0.39835
# 울산 : 0.20341
#
#
#
# 쿠쿠홀딩스
# 주요종속회사 : 0.26771
# 지주회사 : 0.88800
#
#
#
# 에스엠
# 미디어 : 0.25409
# 방송 : 0.31501
# 연결회사 : 0.30349
# 콘텐츠 : 0.76304
#
#
#
# LG하우시스
# lg : 0.27253
# 특허법 : 0.64990
# 필름 : 0.61407
#
#
#
# 엘앤에프
# 리튬 : 0.82162
# 양극 : 0.35135
# 전지 : 0.39639
#
#
#
# 영원무역홀딩스
# 매출액 영업이익 : 0.70771
# 연결회사 : 0.22387
# 주요종속회사 : 0.39804
# 지주회사 : 0.42010
#
#
#
# 롯데정보통신
# ai : 0.31009
# 물류 : 0.32118
# 보안 : 0.33035
# 연결회사 : 0.29317
# 연결회사의 : 0.37799
# 오프라인 : 0.26184
# 진단 : 0.22003
# 클라우드 : 0.30165
#
#
#
# 동원시스템즈
# al : 0.31725
# 금액 비율 : 0.20782
# 내수 합계 : 0.25958
# 산업용 : 0.28333
# 수출 내수 : 0.23664
# 수출 내수 합계 : 0.26159
# 식품 : 0.22336
# 연결기업 : 0.45426
# 필름 : 0.34048
#
#
#
# 삼화콘덴서
# 모듈 : 0.20013
# 수량 금액 : 0.24127
# 전력 : 0.32859
# 제조방법 : 0.50266
#
#
#
# 엠씨넥스
# 모듈 : 0.25904
# 차량 : 0.21130
# 카메라 : 0.74885
# 특허청 : 0.56410
#
#
#
# 파마리서치프로덕트
# 의료기기 : 0.37339
# 의약품 : 0.21549
# 임상 : 0.35234
# 재생 : 0.20536
# 조성물 : 0.32677
# 치료 : 0.30642
# 특허청 : 0.41779
#
#
#
# LG상사
#
#
#
# 넥센타이어
# 타이어 : 0.93771
#
#
#
# 롯데손해보험
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-e6b120f4dd48> in <module>
#       3     print(kr_name)
#       4
# ----> 5     for word, score in zip(tfidf_dict, data_array[i,:]):
#       6         if score >0.2:
#       7             print('%s : %.5f'%(word,score))
#
# IndexError: index 300 is out of bounds for axis 0 with size 300

# %% [markdown]
# ### 이 경우에도 나쁘지는 않은것을 확인할 수 있다.
#
# #### 삼성전자
# gb : 0.45105
# oled : 0.25266
# tv : 0.58856
# 디스플레이 : 0.26352
# 반도체 : 0.25505
# 세대 : 0.27782
#
#
#
# #### SK하이닉스
# gb : 0.59842
# pc : 0.21558
# 반도체 : 0.66828
# 카메라 : 0.24741
#
#
#
# #### 삼성바이오로직스
# 계약조건 : 0.21075
# 금액 비중 : 0.33287
# 바이오 : 0.25346
# 바이오의약품 : 0.58871
# 의약품 : 0.48037
# 제약사 : 0.23141
#
#
#
# #### 셀트리온
# 경쟁제품 : 0.39539
# 관련논문 : 0.21472
# 기타사항 : 0.21177
# 의약품 : 0.21025
# 임상 : 0.49020
# 작용기전 : 0.20447
# 적응증 : 0.25126
# 제네릭 : 0.21290
# 항체 : 0.22047
# 향후계획 : 0.21514

# %%
mecab.pos('화학 의외의것')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-1e9cf15adc5d> in <module>
# ----> 1 mecab.pos('화학 의외의것')
#
# NameError: name 'mecab' is not defined
